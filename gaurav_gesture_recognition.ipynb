# %% [markdown]
# ### Project - Gesture Recognition

# %%
#Importing all the required libraries
import numpy as np
from sys import getsizeof
import os
import datetime

# %%
from matplotlib.pyplot import imread
import imageio
import skimage

# %%
#Importing required Keras libraries
from keras.layers import Dropout
from keras.models import Sequential, Model
from keras.layers import Dense, GRU, Flatten, TimeDistributed, Flatten, BatchNormalization, Activation
from keras.layers.convolutional import Conv3D, MaxPooling3D, Conv2D, MaxPooling2D
#from keras.layers.recurrent import LSTM
from keras.callbacks import ModelCheckpoint, ReduceLROnPlateau, EarlyStopping
from keras import optimizers
from keras.layers import Dropout

# %%
#Importing additional libraries
import cv2
import numpy as np
import cv2
import matplotlib.pyplot as plt
import abc
#Ignore warnings during the execution
import warnings
warnings.filterwarnings("ignore")

# %%
np.random.seed(30)
import random as rn
rn.seed(30)
from keras import backend as K
import tensorflow as tf
tf.random.set_seed(30)

# %%
#Reading data from project folder

project_folder='C:/Users/Sudhira/Downloads/Project_data'

# %% [markdown]
# ##### Plotting

# %%
# function to plot the training/validation accuracies/losses.

def plot(history):
    fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(15,4))
    axes[0].plot(history.history['loss'])   
    axes[0].plot(history.history['val_loss'])
    axes[0].legend(['loss','val_loss'])

    axes[1].plot(history.history['categorical_accuracy'])   
    axes[1].plot(history.history['val_categorical_accuracy'])
    axes[1].legend(['categorical_accuracy','val_categorical_accuracy'])

# %% [markdown]
# ## Generator
# This is one of the most important part of the code. The overall structure of the generator has been given. In the generator, you are going to preprocess the images as you have images of 2 different dimensions as well as create a batch of video frames. You have to experiment with `img_idx`, `y`,`z` and normalization such that you get high accuracy.

# %%
class generators(metaclass= abc.ABCMeta):
    # initialisng the path where project data resides
    def initialize_path(self,project_folder):
        self.train_doc = np.random.permutation(open(project_folder + '/' + 'train.csv').readlines())
        self.val_doc = np.random.permutation(open(project_folder + '/' + 'val.csv').readlines())
        self.train_path = project_folder + '/' + 'train'
        self.val_path =  project_folder + '/' + 'val'
        self.num_train_sequences = len(self.train_doc)
        self.num_val_sequences = len(self.val_doc)
    # initialising the image properties    
    def initialize_image_properties(self,image_height=100,image_width=100):
        self.image_height=image_height
        self.image_width=image_width
        self.channels=3
        self.num_classes=5
        self.total_frames=30
    # initialising the batch size, frames to sample and the no. of epochs
    def initialize_hyperparams(self,frames_to_sample=30,batch_size=20,num_epochs=20):
        self.frames_to_sample=frames_to_sample
        self.batch_size=batch_size
        self.num_epochs=num_epochs
        
    # MOST IMPORTANT PART HERE - The generator function        
    def generator(self,source_path, folder_list, augment=False):
        img_idx = np.round(np.linspace(0,self.total_frames-1,self.frames_to_sample)).astype(int)
        batch_size=self.batch_size
        while True:
            t = np.random.permutation(folder_list)
            num_batches = len(t)//batch_size
        
            for batch in range(num_batches): 
                batch_data, batch_labels= self.one_batch_data(source_path,t,batch,batch_size,img_idx,augment)
                yield batch_data, batch_labels 

            remaining_seq=len(t)%batch_size
        
            if (remaining_seq != 0):
                batch_data, batch_labels= self.one_batch_data(source_path,t,num_batches,batch_size,img_idx,augment,remaining_seq)
                yield batch_data, batch_labels 
    
    
    def one_batch_data(self,source_path,t,batch,batch_size,img_idx,augment,remaining_seq=0):
    
        seq_len = remaining_seq if remaining_seq else batch_size
    
        batch_data = np.zeros((seq_len,len(img_idx),self.image_height,self.image_width,self.channels)) 
        batch_labels = np.zeros((seq_len,self.num_classes)) 
    
        if (augment): batch_data_aug = np.zeros((seq_len,len(img_idx),self.image_height,self.image_width,self.channels))

        
        for folder in range(seq_len): 
            imgs = os.listdir(source_path+'/'+ t[folder + (batch*batch_size)].split(';')[0]) 
            for idx,item in enumerate(img_idx):
                #performing image reading and resizing
                image = imageio.imread(source_path+'/'+ t[folder + (batch*batch_size)].strip().split(';')[0]+'/'+imgs[item]).astype(np.float32)
                image_resized=skimage.transform.resize(image,(self.image_height,self.image_width,3))
            
                #normalizing the images
                batch_data[folder,idx,:,:,0] = (image_resized[:,:,0])/255
                batch_data[folder,idx,:,:,1] = (image_resized[:,:,1])/255
                batch_data[folder,idx,:,:,2] = (image_resized[:,:,2])/255
            
                if (augment):
                    shifted = cv2.warpAffine(image, 
                                             np.float32([[1, 0, np.random.randint(-30,30)],[0, 1, np.random.randint(-30,30)]]), 
                                            (image.shape[1], image.shape[0]))
                    
                    gray = cv2.cvtColor(shifted,cv2.COLOR_BGR2GRAY)

                    x0, y0 = np.argwhere(gray > 0).min(axis=0)
                    x1, y1 = np.argwhere(gray > 0).max(axis=0) 
                    # cropping the images to have the targeted gestures and remove the noise from the images.
                    cropped=shifted[x0:x1,y0:y1,:]
                    
                    image_resized=skimage.transform.resize(cropped,(self.image_height,self.image_width,3))
                    
                    #shifted = cv2.warpAffine(image_resized, 
                    #                        np.float32([[1, 0, np.random.randint(-3,3)],[0, 1, np.random.randint(-3,3)]]), 
                    #                        (image_resized.shape[1], image_resized.shape[0]))
            
                    batch_data_aug[folder,idx,:,:,0] = (image_resized[:,:,0])/255
                    batch_data_aug[folder,idx,:,:,1] = (image_resized[:,:,1])/255
                    batch_data_aug[folder,idx,:,:,2] = (image_resized[:,:,2])/255
                
            
            batch_labels[folder, int(t[folder + (batch*batch_size)].strip().split(';')[2])] = 1
            
    
        if (augment):
            batch_data=np.concatenate([batch_data,batch_data_aug])
            batch_labels=np.concatenate([batch_labels,batch_labels])

        
        return(batch_data,batch_labels)
    
    
    def train_model(self, model, augment_data=False):
        train_generator = self.generator(self.train_path, self.train_doc,augment=augment_data)
        val_generator = self.generator(self.val_path, self.val_doc)

        model_name = 'model_init' + '_' + str(datetime.datetime.now()).replace(' ','').replace(':','_') + '/'
        
    
        if not os.path.exists(model_name):
            os.mkdir(model_name)
        
        #filepath = model_name + 'model-{epoch:05d}-{loss:.5f}-{categorical_accuracy:.5f}-{val_loss:.5f}-{val_categorical_accuracy:.5f}.h5'
        filepath = model_name + 'model-{epoch:05d}-{loss:.5f}-{categorical_accuracy:.5f}.h5'
        
        checkpoint = ModelCheckpoint(filepath, monitor='val_loss', verbose=1, save_best_only=True, save_weights_only=False, mode='auto', save_freq=1)
        LR = ReduceLROnPlateau(monitor='val_loss', factor=0.2, verbose=1, patience=4)
        
        earlystop = EarlyStopping( monitor="val_loss", min_delta=0,patience=10,verbose=1)
        callbacks_list = [checkpoint, LR, earlystop]

        if (self.num_train_sequences%self.batch_size) == 0:
            steps_per_epoch = int(self.num_train_sequences/self.batch_size)
        else:
            steps_per_epoch = (self.num_train_sequences//self.batch_size) + 1

        if (self.num_val_sequences%self.batch_size) == 0:
            validation_steps = int(self.num_val_sequences/self.batch_size)
        else:
            validation_steps = (self.num_val_sequences//self.batch_size) + 1
    
        history=model.fit_generator(train_generator, steps_per_epoch=steps_per_epoch, epochs=self.num_epochs, verbose=1, 
                            callbacks=callbacks_list, validation_data=val_generator,
                            validation_steps=validation_steps, class_weight=None, workers=1, initial_epoch=0)
        return history

        
    @abc.abstractmethod
    def define_model(self):
        pass

# %% [markdown]
# ## Model
# Here you make the model using different functionalities that Keras provides. Remember to use `Conv3D` and `MaxPooling3D` and not `Conv2D` and `Maxpooling2D` for a 3D convolution model. You would want to use `TimeDistributed` while building a Conv2D + RNN model. Also remember that the last layer is the softmax. Design the network in such a way that the model is able to give good accuracy on the least number of parameters so that it can fit in the memory of the webcam.

# %% [markdown]
# ## Viz_Rec_model

# %%
class viz_rec_model(generators):
    
    def define_model(self):

        model = Sequential()
        model.add(Conv3D(16, (3, 3, 3), padding='same',
                 input_shape=(self.frames_to_sample,self.image_height,self.image_width,self.channels)))
        model.add(Activation('relu'))
        model.add(BatchNormalization())
        model.add(MaxPooling3D(pool_size=(2, 2, 2)))

        model.add(Conv3D(32, (2, 2, 2), padding='same'))
        model.add(Activation('relu'))
        model.add(BatchNormalization())
        model.add(MaxPooling3D(pool_size=(2, 2, 2)))

        model.add(Conv3D(64, (2, 2, 2), padding='same'))
        model.add(Activation('relu'))
        model.add(BatchNormalization())
        model.add(MaxPooling3D(pool_size=(2, 2, 2)))

        model.add(Conv3D(128, (2, 2, 2), padding='same'))
        model.add(Activation('relu'))
        model.add(BatchNormalization())
        model.add(MaxPooling3D(pool_size=(2, 2, 2)))

        model.add(Flatten())
        model.add(Dense(128,activation='relu'))
        model.add(BatchNormalization())
        model.add(Dropout(0.5))

        model.add(Dense(64,activation='relu'))
        model.add(BatchNormalization())
        model.add(Dropout(0.25))


        model.add(Dense(self.num_classes,activation='softmax'))

        optimiser = optimizers.Adam()
        #optimiser = 'sgd'
        model.compile(optimizer=optimiser, loss='categorical_crossentropy', metrics=['categorical_accuracy'])
        return model

# %%
#Summary check function
# fun - model calling function
#  x  - image hight value
#  y  - image width value
#  m  - batch size value
#  n  - number of pochs

def summary_check(fun,x,y,m,n,o):

    conv_3d=fun()
    conv_3d.initialize_path(project_folder)
    conv_3d.initialize_image_properties(image_height=x,image_width=y)
    conv_3d.initialize_hyperparams(frames_to_sample=m,batch_size=n,num_epochs=0)
    conv_3d_model=conv_3d.define_model()
    result=conv_3d_model.summary()
    return result

# %%
summary_check(viz_rec_model,160,160,20,40,1)
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv3d (Conv3D)             (None, 20, 160, 160, 16)  1312
#
#  activation (Activation)     (None, 20, 160, 160, 16)  0
#
#  batch_normalization (BatchN  (None, 20, 160, 160, 16)  64
#  ormalization)
#
#  max_pooling3d (MaxPooling3D  (None, 10, 80, 80, 16)   0
#  )
#
#  conv3d_1 (Conv3D)           (None, 10, 80, 80, 32)    4128
#
#  activation_1 (Activation)   (None, 10, 80, 80, 32)    0
#
#  batch_normalization_1 (Batc  (None, 10, 80, 80, 32)   128
#  hNormalization)
#
#  max_pooling3d_1 (MaxPooling  (None, 5, 40, 40, 32)    0
#  3D)
#
#  conv3d_2 (Conv3D)           (None, 5, 40, 40, 64)     16448
#
#  activation_2 (Activation)   (None, 5, 40, 40, 64)     0
#
#  batch_normalization_2 (Batc  (None, 5, 40, 40, 64)    256
#  hNormalization)
#
#  max_pooling3d_2 (MaxPooling  (None, 2, 20, 20, 64)    0
#  3D)
#
#  conv3d_3 (Conv3D)           (None, 2, 20, 20, 128)    65664
#
#  activation_3 (Activation)   (None, 2, 20, 20, 128)    0
#
#  batch_normalization_3 (Batc  (None, 2, 20, 20, 128)   512
#  hNormalization)
#
#  max_pooling3d_3 (MaxPooling  (None, 1, 10, 10, 128)   0
#  3D)
#
#  flatten (Flatten)           (None, 12800)             0
#
#  dense (Dense)               (None, 128)               1638528
#
#  batch_normalization_4 (Batc  (None, 128)              512
#  hNormalization)
#
#  dropout (Dropout)           (None, 128)               0
#
#  dense_1 (Dense)             (None, 64)                8256
#
#  batch_normalization_5 (Batc  (None, 64)               256
#  hNormalization)
#
#  dropout_1 (Dropout)         (None, 64)                0
#
#  dense_2 (Dense)             (None, 5)                 325
#
# =================================================================
# Total params: 1,736,389
# Trainable params: 1,735,525
# Non-trainable params: 864
# _________________________________________________________________

# %% [markdown]
# ##### Sample Cropping

# %%
test_generator=viz_rec_model()
test_generator.initialize_path(project_folder)
test_generator.initialize_image_properties(image_height=160,image_width=160)
test_generator.initialize_hyperparams(frames_to_sample=30,batch_size=3,num_epochs=1)

g=test_generator.generator(test_generator.val_path,test_generator.val_doc,augment=True)
batch_data, batch_labels=next(g)
fig, axes = plt.subplots(nrows=1, ncols=2)
axes[0].imshow(batch_data[0,15,:,:,:])   
axes[1].imshow(batch_data[3,15,:,:,:])

# %% [markdown]
# ## Experimenting with Image resolution, number of frames to use and batch_size

# %% [markdown]
# #### using summary_check function we can pass in different values for x,y,m,n and can see what is the value range which is perfect to start with
#
# #### Did multiple experiments using different combination of values passed to function and found that bigger the image size training time will be more
#
# #### Hence we will perform our model testing with images of size 160/160 & 120/120 and the batch size will be kept between 15 to 45

# %% [markdown]
# ## Exp_Model_01
# ### Base Model - Batch Size = 40 and No. of Epochs = 15

# %%
class exp_model_01(generators):
    
    def define_model(self,filtersize=(3,3,3),dense_neurons=64,dropout=0.25):

        model = Sequential()
        model.add(Conv3D(16, filtersize, padding='same',
                 input_shape=(self.frames_to_sample,self.image_height,self.image_width,self.channels)))
        model.add(Activation('relu'))
        model.add(BatchNormalization())
        model.add(MaxPooling3D(pool_size=(2, 2, 2)))

        model.add(Conv3D(32, filtersize, padding='same'))
        model.add(Activation('relu'))
        model.add(BatchNormalization())
        model.add(MaxPooling3D(pool_size=(2, 2, 2)))

        model.add(Conv3D(64, filtersize, padding='same'))
        model.add(Activation('relu'))
        model.add(BatchNormalization())
        model.add(MaxPooling3D(pool_size=(2, 2, 2)))

        model.add(Conv3D(128, filtersize, padding='same'))
        model.add(Activation('relu'))
        model.add(BatchNormalization())
        model.add(MaxPooling3D(pool_size=(2, 2, 2)))

        model.add(Flatten())
        model.add(Dense(dense_neurons,activation='relu'))
        model.add(BatchNormalization())
        model.add(Dropout(dropout))

        model.add(Dense(dense_neurons,activation='relu'))
        model.add(BatchNormalization())
        model.add(Dropout(dropout))


        model.add(Dense(self.num_classes,activation='softmax'))

        optimiser = optimizers.Adam()
        model.compile(optimizer=optimiser, loss='categorical_crossentropy', metrics=['categorical_accuracy'])
        return model

# %%
summary_check(exp_model_01,160,160,30,10,15)
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv3d_4 (Conv3D)           (None, 30, 160, 160, 16)  1312
#
#  activation_4 (Activation)   (None, 30, 160, 160, 16)  0
#
#  batch_normalization_6 (Batc  (None, 30, 160, 160, 16)  64
#  hNormalization)
#
#  max_pooling3d_4 (MaxPooling  (None, 15, 80, 80, 16)   0
#  3D)
#
#  conv3d_5 (Conv3D)           (None, 15, 80, 80, 32)    13856
#
#  activation_5 (Activation)   (None, 15, 80, 80, 32)    0
#
#  batch_normalization_7 (Batc  (None, 15, 80, 80, 32)   128
#  hNormalization)
#
#  max_pooling3d_5 (MaxPooling  (None, 7, 40, 40, 32)    0
#  3D)
#
#  conv3d_6 (Conv3D)           (None, 7, 40, 40, 64)     55360
#
#  activation_6 (Activation)   (None, 7, 40, 40, 64)     0
#
#  batch_normalization_8 (Batc  (None, 7, 40, 40, 64)    256
#  hNormalization)
#
#  max_pooling3d_6 (MaxPooling  (None, 3, 20, 20, 64)    0
#  3D)
#
#  conv3d_7 (Conv3D)           (None, 3, 20, 20, 128)    221312
#
#  activation_7 (Activation)   (None, 3, 20, 20, 128)    0
#
#  batch_normalization_9 (Batc  (None, 3, 20, 20, 128)   512
#  hNormalization)
#
#  max_pooling3d_7 (MaxPooling  (None, 1, 10, 10, 128)   0
#  3D)
#
#  flatten_1 (Flatten)         (None, 12800)             0
#
#  dense_3 (Dense)             (None, 64)                819264
#
#  batch_normalization_10 (Bat  (None, 64)               256
#  chNormalization)
#
#  dropout_2 (Dropout)         (None, 64)                0
#
#  dense_4 (Dense)             (None, 64)                4160
#
#  batch_normalization_11 (Bat  (None, 64)               256
#  chNormalization)
#
#  dropout_3 (Dropout)         (None, 64)                0
#
#  dense_5 (Dense)             (None, 5)                 325
#
# =================================================================
# Total params: 1,117,061
# Trainable params: 1,116,325
# Non-trainable params: 736
# _________________________________________________________________

# %%
conv_3d1=exp_model_01()
conv_3d1.initialize_path(project_folder)
conv_3d1.initialize_image_properties(image_height=160,image_width=160)
conv_3d1.initialize_hyperparams(frames_to_sample=20,batch_size=40,num_epochs=15)
conv_3d1_model=conv_3d1.define_model()
conv_3d1_model.summary()
print("Total Params:", conv_3d_model.count_params())
history_model1 = conv_3d1.train_model(conv_3d1_model)
# Out:
# Total Params: 1117061
# Epoch 1/15
# 17/17 [==============================] - 168s 10s/step - loss: 1.7374 - categorical_accuracy: 0.3746 - val_loss: 6.3520 - val_categorical_accuracy: 0.3200
#
# Epoch 00001: val_loss improved from inf to 6.35202, saving model to model_init_2020-06-2515_07_40.208996/model-00001-1.74564-0.37104-6.35202-0.32000.h5
# Epoch 2/15
# 17/17 [==============================] - 55s 3s/step - loss: 1.2724 - categorical_accuracy: 0.5247 - val_loss: 3.1187 - val_categorical_accuracy: 0.2900
#
# Epoch 00002: val_loss improved from 6.35202 to 3.11867, saving model to model_init_2020-06-2515_07_40.208996/model-00002-1.27453-0.52790-3.11867-0.29000.h5
# Epoch 3/15
# 17/17 [==============================] - 59s 3s/step - loss: 0.9921 - categorical_accuracy: 0.6158 - val_loss: 1.2044 - val_categorical_accuracy: 0.5100
#
# Epoch 00003: val_loss improved from 3.11867 to 1.20440, saving model to model_init_2020-06-2515_07_40.208996/model-00003-1.00028-0.61388-1.20440-0.51000.h5
# Epoch 4/15
# 17/17 [==============================] - 58s 3s/step - loss: 0.7925 - categorical_accuracy: 0.7376 - val_loss: 0.8441 - val_categorical_accuracy: 0.6700
#
# Epoch 00004: val_loss improved from 1.20440 to 0.84413, saving model to model_init_2020-06-2515_07_40.208996/model-00004-0.79132-0.73756-0.84413-0.67000.h5
# Epoch 5/15
# 17/17 [==============================] - 58s 3s/step - loss: 0.5836 - categorical_accuracy: 0.7768 - val_loss: 1.1775 - val_categorical_accuracy: 0.6300
#
# Epoch 00005: val_loss did not improve from 0.84413
# Epoch 6/15
# 17/17 [==============================] - 59s 3s/step - loss: 0.4384 - categorical_accuracy: 0.8491 - val_loss: 0.9481 - val_categorical_accuracy: 0.6800
#
# Epoch 00006: val_loss did not improve from 0.84413
# Epoch 7/15
# 17/17 [==============================] - 58s 3s/step - loss: 0.3369 - categorical_accuracy: 0.8831 - val_loss: 1.0296 - val_categorical_accuracy: 0.6400
#
# Epoch 00007: val_loss did not improve from 0.84413
# Epoch 8/15
# 17/17 [==============================] - 59s 3s/step - loss: 0.2387 - categorical_accuracy: 0.9258 - val_loss: 0.9406 - val_categorical_accuracy: 0.6600
#
# Epoch 00008: val_loss did not improve from 0.84413
#
# Epoch 00008: ReduceLROnPlateau reducing learning rate to 0.00020000000949949026.
# Epoch 9/15
# 17/17 [==============================] - 59s 3s/step - loss: 0.1887 - categorical_accuracy: 0.9424 - val_loss: 0.9321 - val_categorical_accuracy: 0.6900
#
# Epoch 00009: val_loss did not improve from 0.84413
# Epoch 10/15
# 17/17 [==============================] - 58s 3s/step - loss: 0.1446 - categorical_accuracy: 0.9720 - val_loss: 0.8745 - val_categorical_accuracy: 0.7000
#
# Epoch 00010: val_loss did not improve from 0.84413
# Epoch 11/15
# 17/17 [==============================] - 58s 3s/step - loss: 0.1322 - categorical_accuracy: 0.9720 - val_loss: 0.6898 - val_categorical_accuracy: 0.7800
#
# Epoch 00011: val_loss improved from 0.84413 to 0.68982, saving model to model_init_2020-06-2515_07_40.208996/model-00011-0.13266-0.97134-0.68982-0.78000.h5
# Epoch 12/15
# 17/17 [==============================] - 59s 3s/step - loss: 0.1189 - categorical_accuracy: 0.9823 - val_loss: 0.6373 - val_categorical_accuracy: 0.8100
#
# Epoch 00012: val_loss improved from 0.68982 to 0.63730, saving model to model_init_2020-06-2515_07_40.208996/model-00012-0.12026-0.98190-0.63730-0.81000.h5
# Epoch 13/15
# 17/17 [==============================] - 58s 3s/step - loss: 0.1126 - categorical_accuracy: 0.9823 - val_loss: 0.6135 - val_categorical_accuracy: 0.8000
#
# Epoch 00013: val_loss improved from 0.63730 to 0.61352, saving model to model_init_2020-06-2515_07_40.208996/model-00013-0.11355-0.98190-0.61352-0.80000.h5
# Epoch 14/15
# 17/17 [==============================] - 59s 3s/step - loss: 0.0967 - categorical_accuracy: 0.9867 - val_loss: 0.5723 - val_categorical_accuracy: 0.7900
#
# Epoch 00014: val_loss improved from 0.61352 to 0.57231, saving model to model_init_2020-06-2515_07_40.208996/model-00014-0.09536-0.98643-0.57231-0.79000.h5
# Epoch 15/15
# 17/17 [==============================] - 59s 3s/step - loss: 0.0870 - categorical_accuracy: 0.9926 - val_loss: 0.5564 - val_categorical_accuracy: 0.8200
#
# Epoch 00015: val_loss improved from 0.57231 to 0.55643, saving model to model_init_2020-06-2515_07_40.208996/model-00015-0.08611-0.99246-0.55643-0.82000.h5

# %%
plot(history_model1)

# %% [markdown]
# ##### Model is clearly overfitting. :(

# %% [markdown]
# ## Exp_Model_02
# ### Adding dropout layers - Batch Size = 20 and No. of Epochs = 25

# %%
summary_check(exp_model_01,160,160,20,20,25)
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv3d_9 (Conv3D)            (None, 20, 160, 160, 16)  1312
# _________________________________________________________________
# activation_9 (Activation)    (None, 20, 160, 160, 16)  0
# _________________________________________________________________
# batch_normalization_13 (Batc (None, 20, 160, 160, 16)  64
# _________________________________________________________________
# max_pooling3d_9 (MaxPooling3 (None, 10, 80, 80, 16)    0
# _________________________________________________________________
# conv3d_10 (Conv3D)           (None, 10, 80, 80, 32)    13856
# _________________________________________________________________
# activation_10 (Activation)   (None, 10, 80, 80, 32)    0
# _________________________________________________________________
# batch_normalization_14 (Batc (None, 10, 80, 80, 32)    128
# _________________________________________________________________
# max_pooling3d_10 (MaxPooling (None, 5, 40, 40, 32)     0
# _________________________________________________________________
# conv3d_11 (Conv3D)           (None, 5, 40, 40, 64)     55360
# _________________________________________________________________
# activation_11 (Activation)   (None, 5, 40, 40, 64)     0
# _________________________________________________________________
# batch_normalization_15 (Batc (None, 5, 40, 40, 64)     256
# _________________________________________________________________
# max_pooling3d_11 (MaxPooling (None, 2, 20, 20, 64)     0
# _________________________________________________________________
# conv3d_12 (Conv3D)           (None, 2, 20, 20, 128)    221312
# _________________________________________________________________
# activation_12 (Activation)   (None, 2, 20, 20, 128)    0
# _________________________________________________________________
# batch_normalization_16 (Batc (None, 2, 20, 20, 128)    512
# _________________________________________________________________
# max_pooling3d_12 (MaxPooling (None, 1, 10, 10, 128)    0
# _________________________________________________________________
# flatten_3 (Flatten)          (None, 12800)             0
# _________________________________________________________________
# dense_7 (Dense)              (None, 256)               3277056
# _________________________________________________________________
# batch_normalization_17 (Batc (None, 256)               1024
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_8 (Dense)              (None, 256)               65792
# _________________________________________________________________
# batch_normalization_18 (Batc (None, 256)               1024
# _________________________________________________________________
# dropout_6 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_9 (Dense)              (None, 5)                 1285
# =================================================================
# Total params: 3,638,981
# Trainable params: 3,637,477
# Non-trainable params: 1,504
# _________________________________________________________________

# %%
conv_3d2=exp_model_01()
conv_3d2.initialize_path(project_folder)
conv_3d2.initialize_image_properties(image_height=160,image_width=160)
conv_3d2.initialize_hyperparams(frames_to_sample=20,batch_size=20,num_epochs=25)
conv_3d2_model=conv_3d2.define_model(dense_neurons=256,dropout=0.5)
conv_3d2_model.summary()
print("Total Params:", conv_3d2_model.count_params())
history_model2=conv_3d2.train_model(conv_3d2_model,augment_data=True)
# Out:
# Total Params: 3638981
# Epoch 1/25
# 34/34 [==============================] - 271s 8s/step - loss: 1.8517 - categorical_accuracy: 0.4176 - val_loss: 3.3451 - val_categorical_accuracy: 0.3000
#
# Epoch 00001: val_loss improved from inf to 3.34514, saving model to model_init_2020-06-2608_48_55.154021/model-00001-1.83434-0.41554-3.34514-0.30000.h5
# Epoch 2/25
# 34/34 [==============================] - 130s 4s/step - loss: 1.3541 - categorical_accuracy: 0.5232 - val_loss: 2.4672 - val_categorical_accuracy: 0.4400
#
# Epoch 00002: val_loss improved from 3.34514 to 2.46718, saving model to model_init_2020-06-2608_48_55.154021/model-00002-1.31038-0.53620-2.46718-0.44000.h5
# Epoch 3/25
# 34/34 [==============================] - 131s 4s/step - loss: 1.2696 - categorical_accuracy: 0.5530 - val_loss: 2.4608 - val_categorical_accuracy: 0.4500
#
# Epoch 00003: val_loss improved from 2.46718 to 2.46076, saving model to model_init_2020-06-2608_48_55.154021/model-00003-1.26373-0.55430-2.46076-0.45000.h5
# Epoch 4/25
# 34/34 [==============================] - 130s 4s/step - loss: 1.2481 - categorical_accuracy: 0.5747 - val_loss: 3.8752 - val_categorical_accuracy: 0.3900
#
# Epoch 00004: val_loss did not improve from 2.46076
# Epoch 5/25
# 34/34 [==============================] - 131s 4s/step - loss: 1.0391 - categorical_accuracy: 0.6166 - val_loss: 1.2422 - val_categorical_accuracy: 0.6000
#
# Epoch 00005: val_loss improved from 2.46076 to 1.24219, saving model to model_init_2020-06-2608_48_55.154021/model-00005-1.04466-0.61538-1.24219-0.60000.h5
# Epoch 6/25
# 34/34 [==============================] - 131s 4s/step - loss: 0.9375 - categorical_accuracy: 0.6542 - val_loss: 1.4102 - val_categorical_accuracy: 0.5200
#
# Epoch 00006: val_loss did not improve from 1.24219
# Epoch 7/25
# 34/34 [==============================] - 130s 4s/step - loss: 0.8823 - categorical_accuracy: 0.6696 - val_loss: 2.9288 - val_categorical_accuracy: 0.4400
#
# Epoch 00007: val_loss did not improve from 1.24219
# Epoch 8/25
# 34/34 [==============================] - 131s 4s/step - loss: 0.8004 - categorical_accuracy: 0.7068 - val_loss: 1.5755 - val_categorical_accuracy: 0.5000
#
# Epoch 00008: val_loss did not improve from 1.24219
# Epoch 9/25
# 34/34 [==============================] - 130s 4s/step - loss: 0.7526 - categorical_accuracy: 0.7252 - val_loss: 2.7438 - val_categorical_accuracy: 0.3900
#
# Epoch 00009: val_loss did not improve from 1.24219
#
# Epoch 00009: ReduceLROnPlateau reducing learning rate to 0.00020000000949949026.
# Epoch 10/25
# 34/34 [==============================] - 129s 4s/step - loss: 0.6072 - categorical_accuracy: 0.7645 - val_loss: 2.2222 - val_categorical_accuracy: 0.4400
#
# Epoch 00010: val_loss did not improve from 1.24219
# Epoch 11/25
# 34/34 [==============================] - 129s 4s/step - loss: 0.5648 - categorical_accuracy: 0.7840 - val_loss: 2.3426 - val_categorical_accuracy: 0.4000
#
# Epoch 00011: val_loss did not improve from 1.24219
# Epoch 12/25
# 34/34 [==============================] - 130s 4s/step - loss: 0.4940 - categorical_accuracy: 0.8153 - val_loss: 2.1381 - val_categorical_accuracy: 0.4500
#
# Epoch 00012: val_loss did not improve from 1.24219
# Epoch 13/25
# 34/34 [==============================] - 129s 4s/step - loss: 0.4645 - categorical_accuracy: 0.8344 - val_loss: 2.0177 - val_categorical_accuracy: 0.4400
#
# Epoch 00013: val_loss did not improve from 1.24219
#
# Epoch 00013: ReduceLROnPlateau reducing learning rate to 4.0000001899898055e-05.
# Epoch 14/25
# 34/34 [==============================] - 130s 4s/step - loss: 0.5573 - categorical_accuracy: 0.8090 - val_loss: 1.6437 - val_categorical_accuracy: 0.5200
#
# Epoch 00014: val_loss did not improve from 1.24219
# Epoch 15/25
# 34/34 [==============================] - 128s 4s/step - loss: 0.4782 - categorical_accuracy: 0.8068 - val_loss: 1.2808 - val_categorical_accuracy: 0.5800
#
# Epoch 00015: val_loss did not improve from 1.24219
# Epoch 00015: early stopping

# %%
plot(history_model2)

# %% [markdown]
# ##### val_loss improvement didn't happened so had to stops the epoch !!

# %% [markdown]
# ## Exp_Model_03
# ### Reduce filter size to (2,2,2) and image res to 120 x  120, - Batch Size = 30 and No. of Epochs = 25

# %%
class exp_model_03(ModelBuilder):
    
    def define_model(self,filtersize=(3,3,3),dense_neurons=64,dropout=0.25):

        model = Sequential()
        model.add(Conv3D(16, filtersize, padding='same',
                 input_shape=(self.frames_to_sample,self.image_height,self.image_width,self.channels)))
        model.add(Activation('relu'))
        model.add(BatchNormalization())
        model.add(MaxPooling3D(pool_size=(2, 2, 2)))

        model.add(Conv3D(32, filtersize, padding='same'))
        model.add(Activation('relu'))
        model.add(BatchNormalization())
        model.add(MaxPooling3D(pool_size=(2, 2, 2)))

        model.add(Conv3D(64, filtersize, padding='same'))
        model.add(Activation('relu'))
        model.add(BatchNormalization())
        model.add(MaxPooling3D(pool_size=(2, 2, 2)))

        model.add(Conv3D(128, filtersize, padding='same'))
        model.add(Activation('relu'))
        model.add(BatchNormalization())
        model.add(MaxPooling3D(pool_size=(2, 2, 2)))

        model.add(Flatten())
        model.add(Dense(dense_neurons,activation='relu'))
        model.add(BatchNormalization())
        model.add(Dropout(dropout))

        model.add(Dense(dense_neurons,activation='relu'))
        model.add(BatchNormalization())
        model.add(Dropout(dropout))


        model.add(Dense(self.num_classes,activation='softmax'))
        
        optimiser = optimizers.Adam(lr=0.0002)
        model.compile(optimizer=optimiser, loss='categorical_crossentropy', metrics=['categorical_accuracy'])
        return model

# %%
summary_check(exp_model_03,120,120,16,30,25)
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv3d_9 (Conv3D)            (None, 16, 120, 120, 16)  400
# _________________________________________________________________
# activation_9 (Activation)    (None, 16, 120, 120, 16)  0
# _________________________________________________________________
# batch_normalization_13 (Batc (None, 16, 120, 120, 16)  64
# _________________________________________________________________
# max_pooling3d_9 (MaxPooling3 (None, 8, 60, 60, 16)     0
# _________________________________________________________________
# conv3d_10 (Conv3D)           (None, 8, 60, 60, 32)     4128
# _________________________________________________________________
# activation_10 (Activation)   (None, 8, 60, 60, 32)     0
# _________________________________________________________________
# batch_normalization_14 (Batc (None, 8, 60, 60, 32)     128
# _________________________________________________________________
# max_pooling3d_10 (MaxPooling (None, 4, 30, 30, 32)     0
# _________________________________________________________________
# conv3d_11 (Conv3D)           (None, 4, 30, 30, 64)     16448
# _________________________________________________________________
# activation_11 (Activation)   (None, 4, 30, 30, 64)     0
# _________________________________________________________________
# batch_normalization_15 (Batc (None, 4, 30, 30, 64)     256
# _________________________________________________________________
# max_pooling3d_11 (MaxPooling (None, 2, 15, 15, 64)     0
# _________________________________________________________________
# conv3d_12 (Conv3D)           (None, 2, 15, 15, 128)    65664
# _________________________________________________________________
# activation_12 (Activation)   (None, 2, 15, 15, 128)    0
# _________________________________________________________________
# batch_normalization_16 (Batc (None, 2, 15, 15, 128)    512
# _________________________________________________________________
# max_pooling3d_12 (MaxPooling (None, 1, 7, 7, 128)      0
# _________________________________________________________________
# flatten_3 (Flatten)          (None, 6272)              0
# _________________________________________________________________
# dense_7 (Dense)              (None, 256)               1605888
# _________________________________________________________________
# batch_normalization_17 (Batc (None, 256)               1024
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_8 (Dense)              (None, 256)               65792
# _________________________________________________________________
# batch_normalization_18 (Batc (None, 256)               1024
# _________________________________________________________________
# dropout_6 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_9 (Dense)              (None, 5)                 1285
# =================================================================
# Total params: 1,762,613
# Trainable params: 1,761,109
# Non-trainable params: 1,504
# _________________________________________________________________

# %%
conv_3d3=exp_model_03()
conv_3d3.initialize_path(project_folder)
conv_3d3.initialize_image_properties(image_height=120,image_width=120)
conv_3d3.initialize_hyperparams(frames_to_sample=16,batch_size=30,num_epochs=25)
conv_3d3_model=conv_3d3.define_model(filtersize=(2,2,2),dense_neurons=256,dropout=0.5)
conv_3d3_model.summary()
print("Total Params:", conv_3d3_model.count_params())
history_model3=conv_3d3.train_model(conv_3d3_model,augment_data=True)
# Out:
# Total Params: 1762613
# Epoch 1/25
# 23/23 [==============================] - 179s 8s/step - loss: 2.1232 - categorical_accuracy: 0.3300 - val_loss: 1.3634 - val_categorical_accuracy: 0.4900
#
# Epoch 00001: val_loss improved from inf to 1.36336, saving model to model_init_2020-06-2518_51_55.424666/model-00001-2.14420-0.33635-1.36336-0.49000.h5
# Epoch 2/25
# 23/23 [==============================] - 87s 4s/step - loss: 1.5574 - categorical_accuracy: 0.4724 - val_loss: 0.9969 - val_categorical_accuracy: 0.6500
#
# Epoch 00002: val_loss improved from 1.36336 to 0.99685, saving model to model_init_2020-06-2518_51_55.424666/model-00002-1.53478-0.47134-0.99685-0.65000.h5
# Epoch 3/25
# 23/23 [==============================] - 88s 4s/step - loss: 1.3037 - categorical_accuracy: 0.5360 - val_loss: 0.9414 - val_categorical_accuracy: 0.6900
#
# Epoch 00003: val_loss improved from 0.99685 to 0.94135, saving model to model_init_2020-06-2518_51_55.424666/model-00003-1.32662-0.53092-0.94135-0.69000.h5
# Epoch 4/25
# 23/23 [==============================] - 87s 4s/step - loss: 1.2274 - categorical_accuracy: 0.5537 - val_loss: 0.8929 - val_categorical_accuracy: 0.6900
#
# Epoch 00004: val_loss improved from 0.94135 to 0.89287, saving model to model_init_2020-06-2518_51_55.424666/model-00004-1.24013-0.55581-0.89287-0.69000.h5
# Epoch 5/25
# 23/23 [==============================] - 87s 4s/step - loss: 1.1009 - categorical_accuracy: 0.5980 - val_loss: 0.9524 - val_categorical_accuracy: 0.6700
#
# Epoch 00005: val_loss did not improve from 0.89287
# Epoch 6/25
# 23/23 [==============================] - 87s 4s/step - loss: 1.0413 - categorical_accuracy: 0.6338 - val_loss: 0.8838 - val_categorical_accuracy: 0.7100
#
# Epoch 00006: val_loss improved from 0.89287 to 0.88382, saving model to model_init_2020-06-2518_51_55.424666/model-00006-0.97831-0.64555-0.88382-0.71000.h5
# Epoch 7/25
# 23/23 [==============================] - 87s 4s/step - loss: 0.9550 - categorical_accuracy: 0.6561 - val_loss: 0.8705 - val_categorical_accuracy: 0.7000
#
# Epoch 00007: val_loss improved from 0.88382 to 0.87047, saving model to model_init_2020-06-2518_51_55.424666/model-00007-0.95739-0.66214-0.87047-0.70000.h5
# Epoch 8/25
# 23/23 [==============================] - 86s 4s/step - loss: 0.8914 - categorical_accuracy: 0.6839 - val_loss: 0.8120 - val_categorical_accuracy: 0.7100
#
# Epoch 00008: val_loss improved from 0.87047 to 0.81198, saving model to model_init_2020-06-2518_51_55.424666/model-00008-0.83746-0.69759-0.81198-0.71000.h5
# Epoch 9/25
# 23/23 [==============================] - 86s 4s/step - loss: 0.8239 - categorical_accuracy: 0.7118 - val_loss: 0.8288 - val_categorical_accuracy: 0.7100
#
# Epoch 00009: val_loss did not improve from 0.81198
# Epoch 10/25
# 23/23 [==============================] - 86s 4s/step - loss: 0.8126 - categorical_accuracy: 0.7001 - val_loss: 0.8028 - val_categorical_accuracy: 0.7200
#
# Epoch 00010: val_loss improved from 0.81198 to 0.80284, saving model to model_init_2020-06-2518_51_55.424666/model-00010-0.81161-0.70136-0.80284-0.72000.h5
# Epoch 11/25
# 23/23 [==============================] - 86s 4s/step - loss: 0.8011 - categorical_accuracy: 0.7072 - val_loss: 0.8610 - val_categorical_accuracy: 0.7200
#
# Epoch 00011: val_loss did not improve from 0.80284
# Epoch 12/25
# 23/23 [==============================] - 87s 4s/step - loss: 0.6643 - categorical_accuracy: 0.7629 - val_loss: 0.7437 - val_categorical_accuracy: 0.7200
#
# Epoch 00012: val_loss improved from 0.80284 to 0.74366, saving model to model_init_2020-06-2518_51_55.424666/model-00012-0.67078-0.76018-0.74366-0.72000.h5
# Epoch 13/25
# 23/23 [==============================] - 88s 4s/step - loss: 0.6617 - categorical_accuracy: 0.7526 - val_loss: 0.8085 - val_categorical_accuracy: 0.7100
#
# Epoch 00013: val_loss did not improve from 0.74366
# Epoch 14/25
# 23/23 [==============================] - 87s 4s/step - loss: 0.6086 - categorical_accuracy: 0.7747 - val_loss: 0.7865 - val_categorical_accuracy: 0.7500
#
# Epoch 00014: val_loss did not improve from 0.74366
# Epoch 15/25
# 23/23 [==============================] - 87s 4s/step - loss: 0.7149 - categorical_accuracy: 0.7838 - val_loss: 0.8909 - val_categorical_accuracy: 0.6900
#
# Epoch 00015: val_loss did not improve from 0.74366
# Epoch 16/25
# 23/23 [==============================] - 88s 4s/step - loss: 0.6506 - categorical_accuracy: 0.7749 - val_loss: 0.8993 - val_categorical_accuracy: 0.6800
#
# Epoch 00016: val_loss did not improve from 0.74366
#
# Epoch 00016: ReduceLROnPlateau reducing learning rate to 3.9999998989515007e-05.
# Epoch 17/25
# 23/23 [==============================] - 88s 4s/step - loss: 0.5707 - categorical_accuracy: 0.7940 - val_loss: 0.8520 - val_categorical_accuracy: 0.7100
#
# Epoch 00017: val_loss did not improve from 0.74366
# Epoch 18/25
# 23/23 [==============================] - 88s 4s/step - loss: 0.5327 - categorical_accuracy: 0.8024 - val_loss: 0.7979 - val_categorical_accuracy: 0.7400
#
# Epoch 00018: val_loss did not improve from 0.74366
# Epoch 19/25
# 23/23 [==============================] - 87s 4s/step - loss: 0.5878 - categorical_accuracy: 0.7848 - val_loss: 0.7667 - val_categorical_accuracy: 0.7700
#
# Epoch 00019: val_loss did not improve from 0.74366
# Epoch 20/25
# 23/23 [==============================] - 87s 4s/step - loss: 0.5198 - categorical_accuracy: 0.8181 - val_loss: 0.7769 - val_categorical_accuracy: 0.7500
#
# Epoch 00020: val_loss did not improve from 0.74366
#
# Epoch 00020: ReduceLROnPlateau reducing learning rate to 7.999999797903002e-06.
# Epoch 21/25
# 23/23 [==============================] - 88s 4s/step - loss: 0.4558 - categorical_accuracy: 0.8365 - val_loss: 0.7740 - val_categorical_accuracy: 0.7500
#
# Epoch 00021: val_loss did not improve from 0.74366
# Epoch 22/25
# 23/23 [==============================] - 88s 4s/step - loss: 0.4202 - categorical_accuracy: 0.8497 - val_loss: 0.7723 - val_categorical_accuracy: 0.7700
#
# Epoch 00022: val_loss did not improve from 0.74366
# Epoch 00022: early stopping

# %%
plot(history_model3)

# %% [markdown]
# ##### Model has a  best validation accuracy of 72% and training accuracy of 76% .
# ##### And we are increasing the parameter size as well

# %% [markdown]
# ## Exp_Model_04 -
# ### Adding more layers - Batch Size = 20 and No. of Epochs = 25

# %%
class exp_model_03(ModelBuilder):
    
    def define_model(self,filtersize=(3,3,3),dense_neurons=64,dropout=0.25):

        model = Sequential()
        model.add(Conv3D(16, filtersize, padding='same',
                 input_shape=(self.frames_to_sample,self.image_height,self.image_width,self.channels)))
        model.add(Activation('relu'))
        model.add(BatchNormalization())
        
        model.add(Conv3D(16, filtersize, padding='same',
                 input_shape=(self.frames_to_sample,self.image_height,self.image_width,self.channels)))
        model.add(Activation('relu'))
        model.add(BatchNormalization())
        
        model.add(MaxPooling3D(pool_size=(2, 2, 2)))

        model.add(Conv3D(32, filtersize, padding='same'))
        model.add(Activation('relu'))
        model.add(BatchNormalization())
        
        model.add(Conv3D(32, filtersize, padding='same'))
        model.add(Activation('relu'))
        model.add(BatchNormalization())
        
        model.add(MaxPooling3D(pool_size=(2, 2, 2)))

        model.add(Conv3D(64, filtersize, padding='same'))
        model.add(Activation('relu'))
        model.add(BatchNormalization())
        
        model.add(Conv3D(64, filtersize, padding='same'))
        model.add(Activation('relu'))
        model.add(BatchNormalization())
        
        model.add(MaxPooling3D(pool_size=(2, 2, 2)))

        model.add(Conv3D(128, filtersize, padding='same'))
        model.add(Activation('relu'))
        model.add(BatchNormalization())
        
        model.add(Conv3D(128, filtersize, padding='same'))
        model.add(Activation('relu'))
        model.add(BatchNormalization())
        
        model.add(MaxPooling3D(pool_size=(2, 2, 2)))
        

        model.add(Flatten())
        model.add(Dense(dense_neurons,activation='relu'))
        model.add(BatchNormalization())
        model.add(Dropout(dropout))

        model.add(Dense(dense_neurons,activation='relu'))
        model.add(BatchNormalization())
        model.add(Dropout(dropout))


        model.add(Dense(self.num_classes,activation='softmax'))

        optimiser = optimizers.Adam()
        model.compile(optimizer=optimiser, loss='categorical_crossentropy', metrics=['categorical_accuracy'])
        return model

# %%
summary_check(exp_model_03,160,160,30,10,1)
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv3d_13 (Conv3D)           (None, 16, 120, 120, 16)  1312
# _________________________________________________________________
# activation_13 (Activation)   (None, 16, 120, 120, 16)  0
# _________________________________________________________________
# batch_normalization_19 (Batc (None, 16, 120, 120, 16)  64
# _________________________________________________________________
# conv3d_14 (Conv3D)           (None, 16, 120, 120, 16)  6928
# _________________________________________________________________
# activation_14 (Activation)   (None, 16, 120, 120, 16)  0
# _________________________________________________________________
# batch_normalization_20 (Batc (None, 16, 120, 120, 16)  64
# _________________________________________________________________
# max_pooling3d_13 (MaxPooling (None, 8, 60, 60, 16)     0
# _________________________________________________________________
# conv3d_15 (Conv3D)           (None, 8, 60, 60, 32)     13856
# _________________________________________________________________
# activation_15 (Activation)   (None, 8, 60, 60, 32)     0
# _________________________________________________________________
# batch_normalization_21 (Batc (None, 8, 60, 60, 32)     128
# _________________________________________________________________
# conv3d_16 (Conv3D)           (None, 8, 60, 60, 32)     27680
# _________________________________________________________________
# activation_16 (Activation)   (None, 8, 60, 60, 32)     0
# _________________________________________________________________
# batch_normalization_22 (Batc (None, 8, 60, 60, 32)     128
# _________________________________________________________________
# max_pooling3d_14 (MaxPooling (None, 4, 30, 30, 32)     0
# _________________________________________________________________
# conv3d_17 (Conv3D)           (None, 4, 30, 30, 64)     55360
# _________________________________________________________________
# activation_17 (Activation)   (None, 4, 30, 30, 64)     0
# _________________________________________________________________
# batch_normalization_23 (Batc (None, 4, 30, 30, 64)     256
# _________________________________________________________________
# conv3d_18 (Conv3D)           (None, 4, 30, 30, 64)     110656
# _________________________________________________________________
# activation_18 (Activation)   (None, 4, 30, 30, 64)     0
# _________________________________________________________________
# batch_normalization_24 (Batc (None, 4, 30, 30, 64)     256
# _________________________________________________________________
# max_pooling3d_15 (MaxPooling (None, 2, 15, 15, 64)     0
# _________________________________________________________________
# conv3d_19 (Conv3D)           (None, 2, 15, 15, 128)    221312
# _________________________________________________________________
# activation_19 (Activation)   (None, 2, 15, 15, 128)    0
# _________________________________________________________________
# batch_normalization_25 (Batc (None, 2, 15, 15, 128)    512
# _________________________________________________________________
# conv3d_20 (Conv3D)           (None, 2, 15, 15, 128)    442496
# _________________________________________________________________
# activation_20 (Activation)   (None, 2, 15, 15, 128)    0
# _________________________________________________________________
# batch_normalization_26 (Batc (None, 2, 15, 15, 128)    512
# _________________________________________________________________
# max_pooling3d_16 (MaxPooling (None, 1, 7, 7, 128)      0
# _________________________________________________________________
# flatten_4 (Flatten)          (None, 6272)              0
# _________________________________________________________________
# dense_10 (Dense)             (None, 256)               1605888
# _________________________________________________________________
# batch_normalization_27 (Batc (None, 256)               1024
# _________________________________________________________________
# dropout_7 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_11 (Dense)             (None, 256)               65792
# _________________________________________________________________
# batch_normalization_28 (Batc (None, 256)               1024
# _________________________________________________________________
# dropout_8 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_12 (Dense)             (None, 5)                 1285
# =================================================================
# Total params: 2,556,533
# Trainable params: 2,554,549
# Non-trainable params: 1,984
# _________________________________________________________________

# %%
conv_3d4=exp_model_03()
conv_3d4.initialize_path(project_folder)
conv_3d4.initialize_image_properties(image_height=120,image_width=120)
conv_3d4.initialize_hyperparams(frames_to_sample=16,batch_size=20,num_epochs=25)
conv_3d4_model=conv_3d4.define_model(filtersize=(3,3,3),dense_neurons=256,dropout=0.5)
conv_3d4_model.summary()
print("Total Params:", conv_3d4_model.count_params())
history_model4=conv_3d4.train_model(conv_3d4_model,augment_data=True)
# Out:
# Total Params: 2556533
# Epoch 1/25
# 34/34 [==============================] - 111s 3s/step - loss: 2.1510 - categorical_accuracy: 0.3216 - val_loss: 3.9757 - val_categorical_accuracy: 0.3100
#
# Epoch 00001: val_loss improved from inf to 3.97568, saving model to model_init_2020-06-2519_33_38.502782/model-00001-2.12901-0.32127-3.97568-0.31000.h5
# Epoch 2/25
# 34/34 [==============================] - 92s 3s/step - loss: 1.7173 - categorical_accuracy: 0.3672 - val_loss: 2.1108 - val_categorical_accuracy: 0.4800
#
# Epoch 00002: val_loss improved from 3.97568 to 2.11079, saving model to model_init_2020-06-2519_33_38.502782/model-00002-1.73311-0.35973-2.11079-0.48000.h5
# Epoch 3/25
# 34/34 [==============================] - 95s 3s/step - loss: 1.5333 - categorical_accuracy: 0.4849 - val_loss: 1.5405 - val_categorical_accuracy: 0.5000
#
# Epoch 00003: val_loss improved from 2.11079 to 1.54047, saving model to model_init_2020-06-2519_33_38.502782/model-00003-1.50331-0.48039-1.54047-0.50000.h5
# Epoch 4/25
# 34/34 [==============================] - 96s 3s/step - loss: 1.4638 - categorical_accuracy: 0.4993 - val_loss: 1.9528 - val_categorical_accuracy: 0.5000
#
# Epoch 00004: val_loss did not improve from 1.54047
# Epoch 5/25
# 34/34 [==============================] - 96s 3s/step - loss: 1.2628 - categorical_accuracy: 0.5581 - val_loss: 0.9146 - val_categorical_accuracy: 0.5800
#
# Epoch 00005: val_loss improved from 1.54047 to 0.91456, saving model to model_init_2020-06-2519_33_38.502782/model-00005-1.23949-0.56787-0.91456-0.58000.h5
# Epoch 6/25
# 34/34 [==============================] - 97s 3s/step - loss: 1.1386 - categorical_accuracy: 0.5854 - val_loss: 1.2280 - val_categorical_accuracy: 0.6000
#
# Epoch 00006: val_loss did not improve from 0.91456
# Epoch 7/25
# 34/34 [==============================] - 96s 3s/step - loss: 1.0884 - categorical_accuracy: 0.5846 - val_loss: 1.3481 - val_categorical_accuracy: 0.5600
#
# Epoch 00007: val_loss did not improve from 0.91456
# Epoch 8/25
# 34/34 [==============================] - 95s 3s/step - loss: 0.9982 - categorical_accuracy: 0.6405 - val_loss: 4.8598 - val_categorical_accuracy: 0.4600
#
# Epoch 00008: val_loss did not improve from 0.91456
# Epoch 9/25
# 34/34 [==============================] - 96s 3s/step - loss: 1.0742 - categorical_accuracy: 0.6074 - val_loss: 1.6597 - val_categorical_accuracy: 0.5700
#
# Epoch 00009: val_loss did not improve from 0.91456
#
# Epoch 00009: ReduceLROnPlateau reducing learning rate to 0.00020000000949949026.
# Epoch 10/25
# 34/34 [==============================] - 96s 3s/step - loss: 0.8070 - categorical_accuracy: 0.7060 - val_loss: 0.9446 - val_categorical_accuracy: 0.7300
#
# Epoch 00010: val_loss did not improve from 0.91456
# Epoch 11/25
# 34/34 [==============================] - 96s 3s/step - loss: 0.7779 - categorical_accuracy: 0.7046 - val_loss: 0.7832 - val_categorical_accuracy: 0.7400
#
# Epoch 00011: val_loss improved from 0.91456 to 0.78325, saving model to model_init_2020-06-2519_33_38.502782/model-00011-0.74018-0.70965-0.78325-0.74000.h5
# Epoch 12/25
# 34/34 [==============================] - 97s 3s/step - loss: 0.7828 - categorical_accuracy: 0.7049 - val_loss: 0.7038 - val_categorical_accuracy: 0.7600
#
# Epoch 00012: val_loss improved from 0.78325 to 0.70375, saving model to model_init_2020-06-2519_33_38.502782/model-00012-0.73612-0.71418-0.70375-0.76000.h5
# Epoch 13/25
# 34/34 [==============================] - 94s 3s/step - loss: 0.6785 - categorical_accuracy: 0.7487 - val_loss: 0.6707 - val_categorical_accuracy: 0.7800
#
# Epoch 00013: val_loss improved from 0.70375 to 0.67065, saving model to model_init_2020-06-2519_33_38.502782/model-00013-0.64837-0.75490-0.67065-0.78000.h5
# Epoch 14/25
# 34/34 [==============================] - 95s 3s/step - loss: 0.6290 - categorical_accuracy: 0.7660 - val_loss: 0.6564 - val_categorical_accuracy: 0.7600
#
# Epoch 00014: val_loss improved from 0.67065 to 0.65642, saving model to model_init_2020-06-2519_33_38.502782/model-00014-0.64241-0.76018-0.65642-0.76000.h5
# Epoch 15/25
# 34/34 [==============================] - 96s 3s/step - loss: 0.6723 - categorical_accuracy: 0.7506 - val_loss: 0.7058 - val_categorical_accuracy: 0.7600
#
# Epoch 00015: val_loss did not improve from 0.65642
# Epoch 16/25
# 34/34 [==============================] - 93s 3s/step - loss: 0.6162 - categorical_accuracy: 0.7770 - val_loss: 0.7616 - val_categorical_accuracy: 0.7000
#
# Epoch 00016: val_loss did not improve from 0.65642
# Epoch 17/25
# 34/34 [==============================] - 95s 3s/step - loss: 0.5902 - categorical_accuracy: 0.7745 - val_loss: 0.7343 - val_categorical_accuracy: 0.7300
#
# Epoch 00017: val_loss did not improve from 0.65642
# Epoch 18/25
# 34/34 [==============================] - 96s 3s/step - loss: 0.5320 - categorical_accuracy: 0.7947 - val_loss: 0.7419 - val_categorical_accuracy: 0.7400
#
# Epoch 00018: val_loss did not improve from 0.65642
#
# Epoch 00018: ReduceLROnPlateau reducing learning rate to 4.0000001899898055e-05.
# Epoch 19/25
# 34/34 [==============================] - 96s 3s/step - loss: 0.4671 - categorical_accuracy: 0.8245 - val_loss: 0.6687 - val_categorical_accuracy: 0.7600
#
# Epoch 00019: val_loss did not improve from 0.65642
# Epoch 20/25
# 34/34 [==============================] - 94s 3s/step - loss: 0.4883 - categorical_accuracy: 0.8083 - val_loss: 0.6490 - val_categorical_accuracy: 0.7500
#
# Epoch 00020: val_loss improved from 0.65642 to 0.64898, saving model to model_init_2020-06-2519_33_38.502782/model-00020-0.47159-0.81599-0.64898-0.75000.h5
# Epoch 21/25
# 34/34 [==============================] - 96s 3s/step - loss: 0.4238 - categorical_accuracy: 0.8433 - val_loss: 0.6234 - val_categorical_accuracy: 0.7400
#
# Epoch 00021: val_loss improved from 0.64898 to 0.62341, saving model to model_init_2020-06-2519_33_38.502782/model-00021-0.43322-0.83937-0.62341-0.74000.h5
# Epoch 22/25
# 34/34 [==============================] - 98s 3s/step - loss: 0.4461 - categorical_accuracy: 0.8311 - val_loss: 0.6156 - val_categorical_accuracy: 0.7500
#
# Epoch 00022: val_loss improved from 0.62341 to 0.61564, saving model to model_init_2020-06-2519_33_38.502782/model-00022-0.45094-0.83107-0.61564-0.75000.h5
# Epoch 23/25
# 34/34 [==============================] - 97s 3s/step - loss: 0.4290 - categorical_accuracy: 0.8326 - val_loss: 0.6245 - val_categorical_accuracy: 0.7400
#
# Epoch 00023: val_loss did not improve from 0.61564
# Epoch 24/25
# 34/34 [==============================] - 97s 3s/step - loss: 0.3997 - categorical_accuracy: 0.8572 - val_loss: 0.6171 - val_categorical_accuracy: 0.7600
#
# Epoch 00024: val_loss did not improve from 0.61564
# Epoch 25/25
# 34/34 [==============================] - 97s 3s/step - loss: 0.4089 - categorical_accuracy: 0.8344 - val_loss: 0.6140 - val_categorical_accuracy: 0.7600
#
# Epoch 00025: val_loss improved from 0.61564 to 0.61396, saving model to model_init_2020-06-2519_33_38.502782/model-00025-0.38099-0.84691-0.61396-0.76000.h5

# %%
plot(history_model4)

# %% [markdown]
# ##### With the above changes we are not seeing any performance improvement

# %% [markdown]
# ## Exp_Model_05
# ### Adding dropout at convolution layers

# %%
class exp_model_05(ModelBuilder):
    
    def define_model(self,filtersize=(3,3,3),dense_neurons=64,dropout=0.25):

        model = Sequential()
        model.add(Conv3D(16, filtersize, padding='same',
                 input_shape=(self.frames_to_sample,self.image_height,self.image_width,self.channels)))
        model.add(Activation('relu'))
        model.add(BatchNormalization())
        
        model.add(Conv3D(16, filtersize, padding='same',
                 input_shape=(self.frames_to_sample,self.image_height,self.image_width,self.channels)))
        model.add(Activation('relu'))
        model.add(BatchNormalization())
        
        model.add(MaxPooling3D(pool_size=(2, 2, 2)))
        model.add(Dropout(dropout))

        model.add(Conv3D(32, filtersize, padding='same'))
        model.add(Activation('relu'))
        model.add(BatchNormalization())
        
        model.add(Conv3D(32, filtersize, padding='same'))
        model.add(Activation('relu'))
        model.add(BatchNormalization())
        
        model.add(MaxPooling3D(pool_size=(2, 2, 2)))
        model.add(Dropout(dropout))

        model.add(Conv3D(64, filtersize, padding='same'))
        model.add(Activation('relu'))
        model.add(BatchNormalization())
        
        model.add(Conv3D(64, filtersize, padding='same'))
        model.add(Activation('relu'))
        model.add(BatchNormalization())
        
        model.add(MaxPooling3D(pool_size=(2, 2, 2)))
        model.add(Dropout(dropout))

        model.add(Conv3D(128, filtersize, padding='same'))
        model.add(Activation('relu'))
        model.add(BatchNormalization())
        
        model.add(Conv3D(128, filtersize, padding='same'))
        model.add(Activation('relu'))
        model.add(BatchNormalization())
        
        model.add(MaxPooling3D(pool_size=(2, 2, 2)))
        model.add(Dropout(dropout))
        
        model.add(Flatten())
        model.add(Dense(dense_neurons,activation='relu'))
        model.add(BatchNormalization())
        model.add(Dropout(dropout))

        model.add(Dense(dense_neurons,activation='relu'))
        model.add(BatchNormalization())
        model.add(Dropout(dropout))


        model.add(Dense(self.num_classes,activation='softmax'))

        optimiser = optimizers.Adam()
        model.compile(optimizer=optimiser, loss='categorical_crossentropy', metrics=['categorical_accuracy'])
        return model

# %%
summary_check(exp_model_05,120,120,16,20,15)
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv3d_21 (Conv3D)           (None, 16, 120, 120, 16)  1312
# _________________________________________________________________
# activation_21 (Activation)   (None, 16, 120, 120, 16)  0
# _________________________________________________________________
# batch_normalization_29 (Batc (None, 16, 120, 120, 16)  64
# _________________________________________________________________
# conv3d_22 (Conv3D)           (None, 16, 120, 120, 16)  6928
# _________________________________________________________________
# activation_22 (Activation)   (None, 16, 120, 120, 16)  0
# _________________________________________________________________
# batch_normalization_30 (Batc (None, 16, 120, 120, 16)  64
# _________________________________________________________________
# max_pooling3d_17 (MaxPooling (None, 8, 60, 60, 16)     0
# _________________________________________________________________
# dropout_9 (Dropout)          (None, 8, 60, 60, 16)     0
# _________________________________________________________________
# conv3d_23 (Conv3D)           (None, 8, 60, 60, 32)     13856
# _________________________________________________________________
# activation_23 (Activation)   (None, 8, 60, 60, 32)     0
# _________________________________________________________________
# batch_normalization_31 (Batc (None, 8, 60, 60, 32)     128
# _________________________________________________________________
# conv3d_24 (Conv3D)           (None, 8, 60, 60, 32)     27680
# _________________________________________________________________
# activation_24 (Activation)   (None, 8, 60, 60, 32)     0
# _________________________________________________________________
# batch_normalization_32 (Batc (None, 8, 60, 60, 32)     128
# _________________________________________________________________
# max_pooling3d_18 (MaxPooling (None, 4, 30, 30, 32)     0
# _________________________________________________________________
# dropout_10 (Dropout)         (None, 4, 30, 30, 32)     0
# _________________________________________________________________
# conv3d_25 (Conv3D)           (None, 4, 30, 30, 64)     55360
# _________________________________________________________________
# activation_25 (Activation)   (None, 4, 30, 30, 64)     0
# _________________________________________________________________
# batch_normalization_33 (Batc (None, 4, 30, 30, 64)     256
# _________________________________________________________________
# conv3d_26 (Conv3D)           (None, 4, 30, 30, 64)     110656
# _________________________________________________________________
# activation_26 (Activation)   (None, 4, 30, 30, 64)     0
# _________________________________________________________________
# batch_normalization_34 (Batc (None, 4, 30, 30, 64)     256
# _________________________________________________________________
# max_pooling3d_19 (MaxPooling (None, 2, 15, 15, 64)     0
# _________________________________________________________________
# dropout_11 (Dropout)         (None, 2, 15, 15, 64)     0
# _________________________________________________________________
# conv3d_27 (Conv3D)           (None, 2, 15, 15, 128)    221312
# _________________________________________________________________
# activation_27 (Activation)   (None, 2, 15, 15, 128)    0
# _________________________________________________________________
# batch_normalization_35 (Batc (None, 2, 15, 15, 128)    512
# _________________________________________________________________
# conv3d_28 (Conv3D)           (None, 2, 15, 15, 128)    442496
# _________________________________________________________________
# activation_28 (Activation)   (None, 2, 15, 15, 128)    0
# _________________________________________________________________
# batch_normalization_36 (Batc (None, 2, 15, 15, 128)    512
# _________________________________________________________________
# max_pooling3d_20 (MaxPooling (None, 1, 7, 7, 128)      0
# _________________________________________________________________
# dropout_12 (Dropout)         (None, 1, 7, 7, 128)      0
# _________________________________________________________________
# flatten_5 (Flatten)          (None, 6272)              0
# _________________________________________________________________
# dense_13 (Dense)             (None, 256)               1605888
# _________________________________________________________________
# batch_normalization_37 (Batc (None, 256)               1024
# _________________________________________________________________
# dropout_13 (Dropout)         (None, 256)               0
# _________________________________________________________________
# dense_14 (Dense)             (None, 256)               65792
# _________________________________________________________________
# batch_normalization_38 (Batc (None, 256)               1024
# _________________________________________________________________
# dropout_14 (Dropout)         (None, 256)               0
# _________________________________________________________________
# dense_15 (Dense)             (None, 5)                 1285
# =================================================================
# Total params: 2,556,533
# Trainable params: 2,554,549
# Non-trainable params: 1,984
# _________________________________________________________________

# %%
conv_3d5=exp_model_05()
conv_3d5.initialize_path(project_folder)
conv_3d5.initialize_image_properties(image_height=120,image_width=120)
conv_3d5.initialize_hyperparams(frames_to_sample=16,batch_size=20,num_epochs=15)
conv_3d5_model=conv_3d5.define_model(filtersize=(3,3,3),dense_neurons=256,dropout=0.25)
conv_3d5_model.summary()
print("Total Params:", conv_3d5_model.count_params())
history_model5=conv_3d5.train_model(conv_3d5_model,augment_data=True)
# Out:
# Total Params: 2556533
# Epoch 1/15
# 34/34 [==============================] - 109s 3s/step - loss: 1.7731 - categorical_accuracy: 0.3525 - val_loss: 8.6153 - val_categorical_accuracy: 0.2600
#
# Epoch 00001: val_loss improved from inf to 8.61528, saving model to model_init_2020-06-2520_19_44.800564/model-00001-1.76559-0.35294-8.61528-0.26000.h5
# Epoch 2/15
# 34/34 [==============================] - 94s 3s/step - loss: 1.3523 - categorical_accuracy: 0.4963 - val_loss: 2.2637 - val_categorical_accuracy: 0.4100
#
# Epoch 00002: val_loss improved from 8.61528 to 2.26371, saving model to model_init_2020-06-2520_19_44.800564/model-00002-1.32627-0.49623-2.26371-0.41000.h5
# Epoch 3/15
# 34/34 [==============================] - 99s 3s/step - loss: 1.2004 - categorical_accuracy: 0.5456 - val_loss: 3.3482 - val_categorical_accuracy: 0.3700
#
# Epoch 00003: val_loss did not improve from 2.26371
# Epoch 4/15
# 34/34 [==============================] - 98s 3s/step - loss: 1.0521 - categorical_accuracy: 0.5949 - val_loss: 1.9699 - val_categorical_accuracy: 0.4300
#
# Epoch 00004: val_loss improved from 2.26371 to 1.96995, saving model to model_init_2020-06-2520_19_44.800564/model-00004-1.02689-0.60558-1.96995-0.43000.h5
# Epoch 5/15
# 34/34 [==============================] - 99s 3s/step - loss: 0.8838 - categorical_accuracy: 0.6608 - val_loss: 3.4109 - val_categorical_accuracy: 0.3200
#
# Epoch 00005: val_loss did not improve from 1.96995
# Epoch 6/15
# 34/34 [==============================] - 98s 3s/step - loss: 0.8810 - categorical_accuracy: 0.6707 - val_loss: 0.8925 - val_categorical_accuracy: 0.6600
#
# Epoch 00006: val_loss improved from 1.96995 to 0.89245, saving model to model_init_2020-06-2520_19_44.800564/model-00006-0.88966-0.66667-0.89245-0.66000.h5
# Epoch 7/15
# 34/34 [==============================] - 101s 3s/step - loss: 0.6824 - categorical_accuracy: 0.7391 - val_loss: 1.1247 - val_categorical_accuracy: 0.6600
#
# Epoch 00007: val_loss did not improve from 0.89245
# Epoch 8/15
# 34/34 [==============================] - 98s 3s/step - loss: 0.8528 - categorical_accuracy: 0.6924 - val_loss: 1.1001 - val_categorical_accuracy: 0.6800
#
# Epoch 00008: val_loss did not improve from 0.89245
# Epoch 9/15
# 34/34 [==============================] - 99s 3s/step - loss: 0.7631 - categorical_accuracy: 0.7152 - val_loss: 3.0188 - val_categorical_accuracy: 0.5100
#
# Epoch 00009: val_loss did not improve from 0.89245
# Epoch 10/15
# 34/34 [==============================] - 99s 3s/step - loss: 0.7356 - categorical_accuracy: 0.7237 - val_loss: 1.1424 - val_categorical_accuracy: 0.6000
#
# Epoch 00010: val_loss did not improve from 0.89245
#
# Epoch 00010: ReduceLROnPlateau reducing learning rate to 0.00020000000949949026.
# Epoch 11/15
# 34/34 [==============================] - 100s 3s/step - loss: 0.4632 - categorical_accuracy: 0.8300 - val_loss: 0.7158 - val_categorical_accuracy: 0.7400
#
# Epoch 00011: val_loss improved from 0.89245 to 0.71580, saving model to model_init_2020-06-2520_19_44.800564/model-00011-0.45965-0.83409-0.71580-0.74000.h5
# Epoch 12/15
# 34/34 [==============================] - 98s 3s/step - loss: 0.4405 - categorical_accuracy: 0.8418 - val_loss: 0.8221 - val_categorical_accuracy: 0.6900
#
# Epoch 00012: val_loss did not improve from 0.71580
# Epoch 13/15
# 34/34 [==============================] - 100s 3s/step - loss: 0.4177 - categorical_accuracy: 0.8510 - val_loss: 0.8992 - val_categorical_accuracy: 0.6900
#
# Epoch 00013: val_loss did not improve from 0.71580
# Epoch 14/15
# 34/34 [==============================] - 99s 3s/step - loss: 0.4011 - categorical_accuracy: 0.8543 - val_loss: 0.9253 - val_categorical_accuracy: 0.6700
#
# Epoch 00014: val_loss did not improve from 0.71580
# Epoch 15/15
# 34/34 [==============================] - 98s 3s/step - loss: 0.3556 - categorical_accuracy: 0.8823 - val_loss: 0.9057 - val_categorical_accuracy: 0.7200
#
# Epoch 00015: val_loss did not improve from 0.71580
#
# Epoch 00015: ReduceLROnPlateau reducing learning rate to 4.0000001899898055e-05.

# %%
plot(history_model5)

# %% [markdown]
# ##### Above experiment was not helping in any way

# %% [markdown]
# ## Exp_Model_06
# ### Reducing the number of parameters

# %%
class exp_model_06(ModelBuilder):
    
    def define_model(self,dense_neurons=64,dropout=0.25):

        model = Sequential()
        model.add(Conv3D(16, (3, 3, 3), padding='same',
                 input_shape=(self.frames_to_sample,self.image_height,self.image_width,self.channels)))
        model.add(Activation('relu'))
        model.add(BatchNormalization())
        model.add(MaxPooling3D(pool_size=(2, 2, 2)))

        model.add(Conv3D(32, (2, 2, 2), padding='same'))
        model.add(Activation('relu'))
        model.add(BatchNormalization())
        model.add(MaxPooling3D(pool_size=(2, 2, 2)))

        model.add(Conv3D(64, (2, 2, 2), padding='same'))
        model.add(Activation('relu'))
        model.add(BatchNormalization())
        model.add(MaxPooling3D(pool_size=(2, 2, 2)))

        model.add(Conv3D(128, (2, 2, 2), padding='same'))
        model.add(Activation('relu'))
        model.add(BatchNormalization())
        model.add(MaxPooling3D(pool_size=(2, 2, 2)))
        
        model.add(Flatten())
        model.add(Dense(dense_neurons,activation='relu'))
        model.add(BatchNormalization())
        model.add(Dropout(dropout))

        model.add(Dense(dense_neurons,activation='relu'))
        model.add(BatchNormalization())
        model.add(Dropout(dropout))

        model.add(Dense(self.num_classes,activation='softmax'))

        optimiser = optimizers.Adam(lr=0.0002)
        model.compile(optimizer=optimiser, loss='categorical_crossentropy', metrics=['categorical_accuracy'])
        return model

# %%
summary_check(viz_rec_model,100,100,16,20,20)
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv3d_29 (Conv3D)           (None, 16, 100, 100, 16)  1312
# _________________________________________________________________
# activation_29 (Activation)   (None, 16, 100, 100, 16)  0
# _________________________________________________________________
# batch_normalization_39 (Batc (None, 16, 100, 100, 16)  64
# _________________________________________________________________
# max_pooling3d_21 (MaxPooling (None, 8, 50, 50, 16)     0
# _________________________________________________________________
# conv3d_30 (Conv3D)           (None, 8, 50, 50, 32)     4128
# _________________________________________________________________
# activation_30 (Activation)   (None, 8, 50, 50, 32)     0
# _________________________________________________________________
# batch_normalization_40 (Batc (None, 8, 50, 50, 32)     128
# _________________________________________________________________
# max_pooling3d_22 (MaxPooling (None, 4, 25, 25, 32)     0
# _________________________________________________________________
# conv3d_31 (Conv3D)           (None, 4, 25, 25, 64)     16448
# _________________________________________________________________
# activation_31 (Activation)   (None, 4, 25, 25, 64)     0
# _________________________________________________________________
# batch_normalization_41 (Batc (None, 4, 25, 25, 64)     256
# _________________________________________________________________
# max_pooling3d_23 (MaxPooling (None, 2, 12, 12, 64)     0
# _________________________________________________________________
# conv3d_32 (Conv3D)           (None, 2, 12, 12, 128)    65664
# _________________________________________________________________
# activation_32 (Activation)   (None, 2, 12, 12, 128)    0
# _________________________________________________________________
# batch_normalization_42 (Batc (None, 2, 12, 12, 128)    512
# _________________________________________________________________
# max_pooling3d_24 (MaxPooling (None, 1, 6, 6, 128)      0
# _________________________________________________________________
# flatten_6 (Flatten)          (None, 4608)              0
# _________________________________________________________________
# dense_16 (Dense)             (None, 128)               589952
# _________________________________________________________________
# batch_normalization_43 (Batc (None, 128)               512
# _________________________________________________________________
# dropout_15 (Dropout)         (None, 128)               0
# _________________________________________________________________
# dense_17 (Dense)             (None, 128)               16512
# _________________________________________________________________
# batch_normalization_44 (Batc (None, 128)               512
# _________________________________________________________________
# dropout_16 (Dropout)         (None, 128)               0
# _________________________________________________________________
# dense_18 (Dense)             (None, 5)                 645
# =================================================================
# Total params: 696,645
# Trainable params: 695,653
# Non-trainable params: 992
# _________________________________________________________________

# %%
conv_3d6=exp_model_06()
conv_3d6.initialize_path(project_folder)
conv_3d6.initialize_image_properties(image_height=100,image_width=100)
conv_3d6.initialize_hyperparams(frames_to_sample=16,batch_size=20,num_epochs=20)
conv_3d6_model=conv_3d6.define_model(dense_neurons=128,dropout=0.25)
conv_3d6_model.summary()
print("Total Params:", conv_3d6_model.count_params())
history_model6=conv_3d6.train_model(conv_3d6_model,augment_data=True)
# Out:
# Total Params: 696645
# Epoch 1/20
# 34/34 [==============================] - 88s 3s/step - loss: 1.8166 - categorical_accuracy: 0.3561 - val_loss: 1.2759 - val_categorical_accuracy: 0.5000
#
# Epoch 00001: val_loss improved from inf to 1.27593, saving model to model_init_2020-06-2520_50_57.115254/model-00001-1.83981-0.34842-1.27593-0.50000.h5
# Epoch 2/20
# 34/34 [==============================] - 78s 2s/step - loss: 1.2129 - categorical_accuracy: 0.5342 - val_loss: 0.8633 - val_categorical_accuracy: 0.6600
#
# Epoch 00002: val_loss improved from 1.27593 to 0.86331, saving model to model_init_2020-06-2520_50_57.115254/model-00002-1.19631-0.53922-0.86331-0.66000.h5
# Epoch 3/20
# 34/34 [==============================] - 83s 2s/step - loss: 0.9788 - categorical_accuracy: 0.6152 - val_loss: 1.1551 - val_categorical_accuracy: 0.5800
#
# Epoch 00003: val_loss did not improve from 0.86331
# Epoch 4/20
# 34/34 [==============================] - 83s 2s/step - loss: 0.8827 - categorical_accuracy: 0.6589 - val_loss: 0.9667 - val_categorical_accuracy: 0.6500
#
# Epoch 00004: val_loss did not improve from 0.86331
# Epoch 5/20
# 34/34 [==============================] - 83s 2s/step - loss: 0.7812 - categorical_accuracy: 0.6961 - val_loss: 0.8326 - val_categorical_accuracy: 0.7300
#
# Epoch 00005: val_loss improved from 0.86331 to 0.83261, saving model to model_init_2020-06-2520_50_57.115254/model-00005-0.78374-0.69683-0.83261-0.73000.h5
# Epoch 6/20
# 34/34 [==============================] - 83s 2s/step - loss: 0.7510 - categorical_accuracy: 0.7108 - val_loss: 0.9504 - val_categorical_accuracy: 0.6300
#
# Epoch 00006: val_loss did not improve from 0.83261
# Epoch 7/20
# 34/34 [==============================] - 83s 2s/step - loss: 0.6567 - categorical_accuracy: 0.7546 - val_loss: 1.0235 - val_categorical_accuracy: 0.6400
#
# Epoch 00007: val_loss did not improve from 0.83261
# Epoch 8/20
# 34/34 [==============================] - 82s 2s/step - loss: 0.5885 - categorical_accuracy: 0.7789 - val_loss: 1.3001 - val_categorical_accuracy: 0.5900
#
# Epoch 00008: val_loss did not improve from 0.83261
# Epoch 9/20
# 34/34 [==============================] - 82s 2s/step - loss: 0.5872 - categorical_accuracy: 0.7862 - val_loss: 0.9069 - val_categorical_accuracy: 0.7100
#
# Epoch 00009: val_loss did not improve from 0.83261
#
# Epoch 00009: ReduceLROnPlateau reducing learning rate to 3.9999998989515007e-05.
# Epoch 10/20
# 34/34 [==============================] - 82s 2s/step - loss: 0.5001 - categorical_accuracy: 0.8278 - val_loss: 0.8944 - val_categorical_accuracy: 0.6900
#
# Epoch 00010: val_loss did not improve from 0.83261
# Epoch 11/20
# 34/34 [==============================] - 83s 2s/step - loss: 0.4845 - categorical_accuracy: 0.8260 - val_loss: 0.8720 - val_categorical_accuracy: 0.7100
#
# Epoch 00011: val_loss did not improve from 0.83261
# Epoch 12/20
# 34/34 [==============================] - 83s 2s/step - loss: 0.4514 - categorical_accuracy: 0.8484 - val_loss: 0.8168 - val_categorical_accuracy: 0.7400
#
# Epoch 00012: val_loss improved from 0.83261 to 0.81678, saving model to model_init_2020-06-2520_50_57.115254/model-00012-0.44456-0.85294-0.81678-0.74000.h5
# Epoch 13/20
# 34/34 [==============================] - 82s 2s/step - loss: 0.4796 - categorical_accuracy: 0.8282 - val_loss: 0.8252 - val_categorical_accuracy: 0.7200
#
# Epoch 00013: val_loss did not improve from 0.81678
# Epoch 14/20
# 34/34 [==============================] - 83s 2s/step - loss: 0.4373 - categorical_accuracy: 0.8311 - val_loss: 0.8192 - val_categorical_accuracy: 0.7100
#
# Epoch 00014: val_loss did not improve from 0.81678
# Epoch 15/20
# 34/34 [==============================] - 82s 2s/step - loss: 0.4369 - categorical_accuracy: 0.8425 - val_loss: 0.8511 - val_categorical_accuracy: 0.7000
#
# Epoch 00015: val_loss did not improve from 0.81678
# Epoch 16/20
# 34/34 [==============================] - 81s 2s/step - loss: 0.4420 - categorical_accuracy: 0.8480 - val_loss: 0.8697 - val_categorical_accuracy: 0.7000
#
# Epoch 00016: val_loss did not improve from 0.81678
#
# Epoch 00016: ReduceLROnPlateau reducing learning rate to 7.999999797903002e-06.
# Epoch 17/20
# 34/34 [==============================] - 82s 2s/step - loss: 0.4032 - categorical_accuracy: 0.8543 - val_loss: 0.8671 - val_categorical_accuracy: 0.6900
#
# Epoch 00017: val_loss did not improve from 0.81678
# Epoch 18/20
# 34/34 [==============================] - 82s 2s/step - loss: 0.4000 - categorical_accuracy: 0.8628 - val_loss: 0.8660 - val_categorical_accuracy: 0.7000
#
# Epoch 00018: val_loss did not improve from 0.81678
# Epoch 19/20
# 34/34 [==============================] - 81s 2s/step - loss: 0.3770 - categorical_accuracy: 0.8672 - val_loss: 0.8723 - val_categorical_accuracy: 0.6900
#
# Epoch 00019: val_loss did not improve from 0.81678
# Epoch 20/20
# 34/34 [==============================] - 82s 2s/step - loss: 0.4180 - categorical_accuracy: 0.8455 - val_loss: 0.8609 - val_categorical_accuracy: 0.7000
#
# Epoch 00020: val_loss did not improve from 0.81678
#
# Epoch 00020: ReduceLROnPlateau reducing learning rate to 1.5999999959603884e-06.

# %%
plot(history_model6)

# %% [markdown]
# ###### For the above low memory foot print model, we get the best validation accuracy of 74%
# ###### For the above low memory foot print model the best validation accuracy of 73%

# %% [markdown]
# ## Exp_Model_07 - CNN- LSTM Model

# %%
class RNNCNN1(ModelBuilder):
    
    def define_model(self,lstm_cells=64,dense_neurons=64,dropout=0.25):

        model = Sequential()

        model.add(TimeDistributed(Conv2D(16, (3, 3) , padding='same', activation='relu'),
                                  input_shape=(self.frames_to_sample,self.image_height,self.image_width,self.channels)))
        model.add(TimeDistributed(BatchNormalization()))
        model.add(TimeDistributed(MaxPooling2D((2, 2))))
        
        model.add(TimeDistributed(Conv2D(32, (3, 3) , padding='same', activation='relu')))
        model.add(TimeDistributed(BatchNormalization()))
        model.add(TimeDistributed(MaxPooling2D((2, 2))))
        
        model.add(TimeDistributed(Conv2D(64, (3, 3) , padding='same', activation='relu')))
        model.add(TimeDistributed(BatchNormalization()))
        model.add(TimeDistributed(MaxPooling2D((2, 2))))
        
        model.add(TimeDistributed(Conv2D(128, (3, 3) , padding='same', activation='relu')))
        model.add(TimeDistributed(BatchNormalization()))
        model.add(TimeDistributed(MaxPooling2D((2, 2))))
        
        model.add(TimeDistributed(Conv2D(256, (3, 3) , padding='same', activation='relu')))
        model.add(TimeDistributed(BatchNormalization()))
        model.add(TimeDistributed(MaxPooling2D((2, 2))))
        
        #model.add(TimeDistributed(Conv2D(512, (2, 2) , padding='valid', activation='relu')))
       # model.add(TimeDistributed(BatchNormalization()))
       # model.add(TimeDistributed(MaxPooling2D((2, 2))))

        model.add(TimeDistributed(Flatten()))


        model.add(LSTM(lstm_cells))
        model.add(Dropout(dropout))
        
        model.add(Dense(dense_neurons,activation='relu'))
        model.add(Dropout(dropout))
        
        model.add(Dense(self.num_classes, activation='softmax'))
        optimiser = optimizers.Adam()
        model.compile(optimizer=optimiser, loss='categorical_crossentropy', metrics=['categorical_accuracy'])
        return model

# %%
rnn_cnn1=RNNCNN1()
rnn_cnn1.initialize_path(project_folder)
rnn_cnn1.initialize_image_properties(image_height=120,image_width=120)
rnn_cnn1.initialize_hyperparams(frames_to_sample=18,batch_size=20,num_epochs=20)
rnn_cnn1_model=rnn_cnn1.define_model(lstm_cells=128,dense_neurons=128,dropout=0.25)
rnn_cnn1_model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# time_distributed_1 (TimeDist (None, 18, 120, 120, 16)  448
# _________________________________________________________________
# time_distributed_2 (TimeDist (None, 18, 120, 120, 16)  64
# _________________________________________________________________
# time_distributed_3 (TimeDist (None, 18, 60, 60, 16)    0
# _________________________________________________________________
# time_distributed_4 (TimeDist (None, 18, 60, 60, 32)    4640
# _________________________________________________________________
# time_distributed_5 (TimeDist (None, 18, 60, 60, 32)    128
# _________________________________________________________________
# time_distributed_6 (TimeDist (None, 18, 30, 30, 32)    0
# _________________________________________________________________
# time_distributed_7 (TimeDist (None, 18, 30, 30, 64)    18496
# _________________________________________________________________
# time_distributed_8 (TimeDist (None, 18, 30, 30, 64)    256
# _________________________________________________________________
# time_distributed_9 (TimeDist (None, 18, 15, 15, 64)    0
# _________________________________________________________________
# time_distributed_10 (TimeDis (None, 18, 15, 15, 128)   73856
# _________________________________________________________________
# time_distributed_11 (TimeDis (None, 18, 15, 15, 128)   512
# _________________________________________________________________
# time_distributed_12 (TimeDis (None, 18, 7, 7, 128)     0
# _________________________________________________________________
# time_distributed_13 (TimeDis (None, 18, 7, 7, 256)     295168
# _________________________________________________________________
# time_distributed_14 (TimeDis (None, 18, 7, 7, 256)     1024
# _________________________________________________________________
# time_distributed_15 (TimeDis (None, 18, 3, 3, 256)     0
# _________________________________________________________________
# time_distributed_16 (TimeDis (None, 18, 2304)          0
# _________________________________________________________________
# lstm_1 (LSTM)                (None, 128)               1245696
# _________________________________________________________________
# dropout_19 (Dropout)         (None, 128)               0
# _________________________________________________________________
# dense_22 (Dense)             (None, 128)               16512
# _________________________________________________________________
# dropout_20 (Dropout)         (None, 128)               0
# _________________________________________________________________
# dense_23 (Dense)             (None, 5)                 645
# =================================================================
# Total params: 1,657,445
# Trainable params: 1,656,453
# Non-trainable params: 992
# _________________________________________________________________

# %%
print("Total Params:", rnn_cnn1_model.count_params())
history_model8=rnn_cnn1.train_model(rnn_cnn1_model,augment_data=True)
# Out:
# Total Params: 1657445
# Epoch 1/20
# 34/34 [==============================] - 170s 5s/step - loss: 1.4207 - categorical_accuracy: 0.3863 - val_loss: 1.2887 - val_categorical_accuracy: 0.4100
#
# Epoch 00001: val_loss improved from inf to 1.28872, saving model to model_init_2020-06-2522_00_52.036987/model-00001-1.43436-0.37104-1.28872-0.41000.h5
# Epoch 2/20
# 34/34 [==============================] - 91s 3s/step - loss: 1.1351 - categorical_accuracy: 0.5416 - val_loss: 1.1954 - val_categorical_accuracy: 0.5100
#
# Epoch 00002: val_loss improved from 1.28872 to 1.19544, saving model to model_init_2020-06-2522_00_52.036987/model-00002-1.14779-0.53846-1.19544-0.51000.h5
# Epoch 3/20
# 34/34 [==============================] - 98s 3s/step - loss: 1.0247 - categorical_accuracy: 0.5887 - val_loss: 1.5070 - val_categorical_accuracy: 0.3900
#
# Epoch 00003: val_loss did not improve from 1.19544
# Epoch 4/20
# 34/34 [==============================] - 97s 3s/step - loss: 0.9791 - categorical_accuracy: 0.6100 - val_loss: 1.0382 - val_categorical_accuracy: 0.5900
#
# Epoch 00004: val_loss improved from 1.19544 to 1.03823, saving model to model_init_2020-06-2522_00_52.036987/model-00004-0.95777-0.61689-1.03823-0.59000.h5
# Epoch 5/20
# 34/34 [==============================] - 98s 3s/step - loss: 0.8307 - categorical_accuracy: 0.6784 - val_loss: 1.0063 - val_categorical_accuracy: 0.5700
#
# Epoch 00005: val_loss improved from 1.03823 to 1.00627, saving model to model_init_2020-06-2522_00_52.036987/model-00005-0.82406-0.68703-1.00627-0.57000.h5
# Epoch 6/20
# 34/34 [==============================] - 99s 3s/step - loss: 0.7376 - categorical_accuracy: 0.7086 - val_loss: 1.3649 - val_categorical_accuracy: 0.5500
#
# Epoch 00006: val_loss did not improve from 1.00627
# Epoch 7/20
# 34/34 [==============================] - 98s 3s/step - loss: 0.7541 - categorical_accuracy: 0.6906 - val_loss: 1.0793 - val_categorical_accuracy: 0.5800
#
# Epoch 00007: val_loss did not improve from 1.00627
# Epoch 8/20
# 34/34 [==============================] - 97s 3s/step - loss: 0.7483 - categorical_accuracy: 0.7009 - val_loss: 1.6142 - val_categorical_accuracy: 0.4100
#
# Epoch 00008: val_loss did not improve from 1.00627
# Epoch 9/20
# 34/34 [==============================] - 97s 3s/step - loss: 0.5998 - categorical_accuracy: 0.7656 - val_loss: 2.3569 - val_categorical_accuracy: 0.3600
#
# Epoch 00009: val_loss did not improve from 1.00627
#
# Epoch 00009: ReduceLROnPlateau reducing learning rate to 0.00020000000949949026.
# Epoch 10/20
# 34/34 [==============================] - 96s 3s/step - loss: 0.5339 - categorical_accuracy: 0.7954 - val_loss: 1.2725 - val_categorical_accuracy: 0.6000
#
# Epoch 00010: val_loss did not improve from 1.00627
# Epoch 11/20
# 34/34 [==============================] - 97s 3s/step - loss: 0.4418 - categorical_accuracy: 0.8285 - val_loss: 1.0670 - val_categorical_accuracy: 0.6300
#
# Epoch 00011: val_loss did not improve from 1.00627
# Epoch 12/20
# 34/34 [==============================] - 96s 3s/step - loss: 0.3509 - categorical_accuracy: 0.8620 - val_loss: 0.7843 - val_categorical_accuracy: 0.7000
#
# Epoch 00012: val_loss improved from 1.00627 to 0.78430, saving model to model_init_2020-06-2522_00_52.036987/model-00012-0.35327-0.86275-0.78430-0.70000.h5
# Epoch 13/20
# 34/34 [==============================] - 97s 3s/step - loss: 0.3448 - categorical_accuracy: 0.8837 - val_loss: 0.6839 - val_categorical_accuracy: 0.7700
#
# Epoch 00013: val_loss improved from 0.78430 to 0.68387, saving model to model_init_2020-06-2522_00_52.036987/model-00013-0.35164-0.88084-0.68387-0.77000.h5
# Epoch 14/20
# 34/34 [==============================] - 97s 3s/step - loss: 0.3480 - categorical_accuracy: 0.8771 - val_loss: 0.6381 - val_categorical_accuracy: 0.7800
#
# Epoch 00014: val_loss improved from 0.68387 to 0.63815, saving model to model_init_2020-06-2522_00_52.036987/model-00014-0.32830-0.88235-0.63815-0.78000.h5
# Epoch 15/20
# 34/34 [==============================] - 96s 3s/step - loss: 0.3060 - categorical_accuracy: 0.8970 - val_loss: 0.6599 - val_categorical_accuracy: 0.7700
#
# Epoch 00015: val_loss did not improve from 0.63815
# Epoch 16/20
# 34/34 [==============================] - 96s 3s/step - loss: 0.2478 - categorical_accuracy: 0.9110 - val_loss: 0.6088 - val_categorical_accuracy: 0.7500
#
# Epoch 00016: val_loss improved from 0.63815 to 0.60883, saving model to model_init_2020-06-2522_00_52.036987/model-00016-0.24957-0.90875-0.60883-0.75000.h5
# Epoch 17/20
# 34/34 [==============================] - 96s 3s/step - loss: 0.2468 - categorical_accuracy: 0.9117 - val_loss: 0.5588 - val_categorical_accuracy: 0.7800
#
# Epoch 00017: val_loss improved from 0.60883 to 0.55878, saving model to model_init_2020-06-2522_00_52.036987/model-00017-0.23478-0.91780-0.55878-0.78000.h5
# Epoch 18/20
# 34/34 [==============================] - 96s 3s/step - loss: 0.2203 - categorical_accuracy: 0.9191 - val_loss: 0.5375 - val_categorical_accuracy: 0.8100
#
# Epoch 00018: val_loss improved from 0.55878 to 0.53753, saving model to model_init_2020-06-2522_00_52.036987/model-00018-0.21729-0.92534-0.53753-0.81000.h5
# Epoch 19/20
# 34/34 [==============================] - 95s 3s/step - loss: 0.2027 - categorical_accuracy: 0.9367 - val_loss: 0.5269 - val_categorical_accuracy: 0.8200
#
# Epoch 00019: val_loss improved from 0.53753 to 0.52691, saving model to model_init_2020-06-2522_00_52.036987/model-00019-0.20719-0.93514-0.52691-0.82000.h5
# Epoch 20/20
# 34/34 [==============================] - 96s 3s/step - loss: 0.1924 - categorical_accuracy: 0.9367 - val_loss: 0.4570 - val_categorical_accuracy: 0.8500
#
# Epoch 00020: val_loss improved from 0.52691 to 0.45695, saving model to model_init_2020-06-2522_00_52.036987/model-00020-0.19649-0.93514-0.45695-0.85000.h5

# %%
plot(history_model8)

# %% [markdown]
# ##### For CNN - LSTM model we get a best validation accuracy of 85%

# %% [markdown]
# ## Implement data augmentation & check the model performance.

# %%
class ModelBuilderMoreAugmentation(metaclass= abc.ABCMeta):
    
    def initialize_path(self,project_folder):
        self.train_doc = np.random.permutation(open(project_folder + '/' + 'train.csv').readlines())
        self.val_doc = np.random.permutation(open(project_folder + '/' + 'val.csv').readlines())
        self.train_path = project_folder + '/' + 'train'
        self.val_path =  project_folder + '/' + 'val'
        self.num_train_sequences = len(self.train_doc)
        self.num_val_sequences = len(self.val_doc)
        
    def initialize_image_properties(self,image_height=100,image_width=100):
        self.image_height=image_height
        self.image_width=image_width
        self.channels=3
        self.num_classes=5
        self.total_frames=30
          
    def initialize_hyperparams(self,frames_to_sample=30,batch_size=20,num_epochs=20):
        self.frames_to_sample=frames_to_sample
        self.batch_size=batch_size
        self.num_epochs=num_epochs
        
        
    def generator(self,source_path, folder_list, augment=False):
        img_idx = np.round(np.linspace(0,self.total_frames-1,self.frames_to_sample)).astype(int)
        batch_size=self.batch_size
        while True:
            t = np.random.permutation(folder_list)
            num_batches = len(t)//batch_size
        
            for batch in range(num_batches): 
                batch_data, batch_labels= self.one_batch_data(source_path,t,batch,batch_size,img_idx,augment)
                yield batch_data, batch_labels 

            remaining_seq=len(t)%batch_size
        
            if (remaining_seq != 0):
                batch_data, batch_labels= self.one_batch_data(source_path,t,num_batches,batch_size,img_idx,augment,remaining_seq)
                yield batch_data, batch_labels 
    
    
    def one_batch_data(self,source_path,t,batch,batch_size,img_idx,augment,remaining_seq=0):
    
        seq_len = remaining_seq if remaining_seq else batch_size
    
        batch_data = np.zeros((seq_len,len(img_idx),self.image_height,self.image_width,self.channels)) 
        batch_labels = np.zeros((seq_len,self.num_classes)) 
    
        if (augment): batch_data_aug = np.zeros((seq_len,len(img_idx),self.image_height,self.image_width,self.channels))

        
        for folder in range(seq_len): 
            imgs = os.listdir(source_path+'/'+ t[folder + (batch*batch_size)].split(';')[0]) 
            for idx,item in enumerate(img_idx): 
                image = imread(source_path+'/'+ t[folder + (batch*batch_size)].strip().split(';')[0]+'/'+imgs[item]).astype(np.float32)
                image_resized=imresize(image,(self.image_height,self.image_width,3))
            

                batch_data[folder,idx,:,:,0] = (image_resized[:,:,0])/255
                batch_data[folder,idx,:,:,1] = (image_resized[:,:,1])/255
                batch_data[folder,idx,:,:,2] = (image_resized[:,:,2])/255
            
                if (augment):
                    shifted = cv2.warpAffine(image, 
                                             np.float32([[1, 0, np.random.randint(-30,30)],[0, 1, np.random.randint(-30,30)]]), 
                                            (image.shape[1], image.shape[0]))
                    
                    gray = cv2.cvtColor(shifted,cv2.COLOR_BGR2GRAY)

                    x0, y0 = np.argwhere(gray > 0).min(axis=0)
                    x1, y1 = np.argwhere(gray > 0).max(axis=0) 
                    
                    cropped=shifted[x0:x1,y0:y1,:]
                    
                    image_resized=imresize(cropped,(self.image_height,self.image_width,3))
                    
                    M = cv2.getRotationMatrix2D((self.image_width//2,self.image_height//2),
                                                np.random.randint(-10,10), 1.0)
                    rotated = cv2.warpAffine(image_resized, M, (self.image_width, self.image_height))
                    
                    #shifted = cv2.warpAffine(image_resized, 
                    #                        np.float32([[1, 0, np.random.randint(-3,3)],[0, 1, np.random.randint(-3,3)]]), 
                    #                        (image_resized.shape[1], image_resized.shape[0]))
            
                    batch_data_aug[folder,idx,:,:,0] = (rotated[:,:,0])/255
                    batch_data_aug[folder,idx,:,:,1] = (rotated[:,:,1])/255
                    batch_data_aug[folder,idx,:,:,2] = (rotated[:,:,2])/255
                
            
            batch_labels[folder, int(t[folder + (batch*batch_size)].strip().split(';')[2])] = 1
            
    
        if (augment):
            batch_data=np.concatenate([batch_data,batch_data_aug])
            batch_labels=np.concatenate([batch_labels,batch_labels])

        
        return(batch_data,batch_labels)
    
    
    def train_model(self, model, augment_data=False):
        train_generator = self.generator(self.train_path, self.train_doc,augment=augment_data)
        val_generator = self.generator(self.val_path, self.val_doc)

        model_name = 'model_init' + '_' + str(datetime.datetime.now()).replace(' ','').replace(':','_') + '/'
    
        if not os.path.exists(model_name):
            os.mkdir(model_name)
        
        filepath = model_name + 'model-{epoch:05d}-{loss:.5f}-{categorical_accuracy:.5f}-{val_loss:.5f}-{val_categorical_accuracy:.5f}.h5'

        checkpoint = ModelCheckpoint(filepath, monitor='val_loss', verbose=1, save_best_only=False, save_weights_only=False, mode='auto', period=1)
        LR = ReduceLROnPlateau(monitor='val_loss', factor=0.2, verbose=1, patience=4)
        callbacks_list = [checkpoint, LR]

        if (self.num_train_sequences%self.batch_size) == 0:
            steps_per_epoch = int(self.num_train_sequences/self.batch_size)
        else:
            steps_per_epoch = (self.num_train_sequences//self.batch_size) + 1

        if (self.num_val_sequences%self.batch_size) == 0:
            validation_steps = int(self.num_val_sequences/self.batch_size)
        else:
            validation_steps = (self.num_val_sequences//self.batch_size) + 1
    
        history=model.fit_generator(train_generator, steps_per_epoch=steps_per_epoch, epochs=self.num_epochs, verbose=1, 
                            callbacks=callbacks_list, validation_data=val_generator, 
                            validation_steps=validation_steps, class_weight=None, workers=1, initial_epoch=0)
        return history

        
    @abc.abstractmethod
    def define_model(self):
        pass

# %%
class Test(ModelBuilderMoreAugmentation):
    def define_model(self):
        pass

test_generator=Test()
test_generator.initialize_path(project_folder)
test_generator.initialize_image_properties(image_height=160,image_width=160)
test_generator.initialize_hyperparams(frames_to_sample=30,batch_size=3,num_epochs=1)

g=test_generator.generator(test_generator.val_path,test_generator.val_doc,augment=True)
batch_data, batch_labels=next(g)
fig, axes = plt.subplots(nrows=1, ncols=2)
axes[0].imshow(batch_data[0,29,:,:,:])   
axes[1].imshow(batch_data[3,29,:,:,:])

# %% [markdown]
# ### Data augmentation is not helping in data accuracy

# %% [markdown]
# ## Exp_Model_08 - Transfer Learning with GRU and training all weights
# __(Optional)__

# %%
from keras.applications import mobilenet

mobilenet_transfer = mobilenet.MobileNet(weights='imagenet', include_top=False)

class RNNCNN_TL2(ModelBuilderMoreAugmentation):
    
    def define_model(self,gru_cells=64,dense_neurons=64,dropout=0.25):
        
        model = Sequential()
        model.add(TimeDistributed(mobilenet_transfer,input_shape=(self.frames_to_sample,self.image_height,self.image_width,self.channels)))
 
        
        model.add(TimeDistributed(BatchNormalization()))
        model.add(TimeDistributed(MaxPooling2D((2, 2))))
        model.add(TimeDistributed(Flatten()))

        model.add(GRU(gru_cells))
        model.add(Dropout(dropout))
        
        model.add(Dense(dense_neurons,activation='relu'))
        model.add(Dropout(dropout))
        
        model.add(Dense(self.num_classes, activation='softmax'))
        
        
        optimiser = optimizers.Adam()
        model.compile(optimizer=optimiser, loss='categorical_crossentropy', metrics=['categorical_accuracy'])
        return model

# %%
rnn_cnn_tl2=RNNCNN_TL2()
rnn_cnn_tl2.initialize_path(project_folder)
rnn_cnn_tl2.initialize_image_properties(image_height=120,image_width=120)
rnn_cnn_tl2.initialize_hyperparams(frames_to_sample=16,batch_size=5,num_epochs=20)
rnn_cnn_tl2_model=rnn_cnn_tl2.define_model(gru_cells=128,dense_neurons=128,dropout=0.25)
rnn_cnn_tl2_model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# time_distributed_18 (TimeDis (None, 16, 3, 3, 1024)    3228864
# _________________________________________________________________
# time_distributed_19 (TimeDis (None, 16, 3, 3, 1024)    4096
# _________________________________________________________________
# time_distributed_20 (TimeDis (None, 16, 1, 1, 1024)    0
# _________________________________________________________________
# time_distributed_21 (TimeDis (None, 16, 1024)          0
# _________________________________________________________________
# gru_2 (GRU)                  (None, 128)               442752
# _________________________________________________________________
# dropout_9 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense_11 (Dense)             (None, 128)               16512
# _________________________________________________________________
# dropout_10 (Dropout)         (None, 128)               0
# _________________________________________________________________
# dense_12 (Dense)             (None, 5)                 645
# =================================================================
# Total params: 3,692,869
# Trainable params: 3,668,933
# Non-trainable params: 23,936
# _________________________________________________________________

# %%
print("Total Params:", rnn_cnn_tl2_model.count_params())
history_model17=rnn_cnn_tl2.train_model(rnn_cnn_tl2_model,augment_data=True)
# Out:
# Total Params: 3692869
# Epoch 1/20
# 133/133 [==============================] - 94s 710ms/step - loss: 1.3008 - categorical_accuracy: 0.4684 - val_loss: 0.8568 - val_categorical_accuracy: 0.6100
#
# Epoch 00001: saving model to model_init_2020-06-2615_32_34.928124/model-00001-1.30094-0.46833-0.85678-0.61000.h5
# Epoch 2/20
# 133/133 [==============================] - 84s 633ms/step - loss: 0.7789 - categorical_accuracy: 0.6910 - val_loss: 0.4741 - val_categorical_accuracy: 0.8200
#
# Epoch 00002: saving model to model_init_2020-06-2615_32_34.928124/model-00002-0.77215-0.69155-0.47407-0.82000.h5
# Epoch 3/20
# 133/133 [==============================] - 84s 631ms/step - loss: 0.5521 - categorical_accuracy: 0.7785 - val_loss: 0.5637 - val_categorical_accuracy: 0.8000
#
# Epoch 00003: saving model to model_init_2020-06-2615_32_34.928124/model-00003-0.55135-0.77979-0.56365-0.80000.h5
# Epoch 4/20
# 133/133 [==============================] - 84s 635ms/step - loss: 0.4340 - categorical_accuracy: 0.8326 - val_loss: 0.2913 - val_categorical_accuracy: 0.9000
#
# Epoch 00004: saving model to model_init_2020-06-2615_32_34.928124/model-00004-0.43322-0.83258-0.29126-0.90000.h5
# Epoch 5/20
# 133/133 [==============================] - 83s 622ms/step - loss: 0.4720 - categorical_accuracy: 0.8306 - val_loss: 0.7167 - val_categorical_accuracy: 0.7500
#
# Epoch 00005: saving model to model_init_2020-06-2615_32_34.928124/model-00005-0.47229-0.83107-0.71670-0.75000.h5
# Epoch 6/20
# 133/133 [==============================] - 84s 634ms/step - loss: 0.3542 - categorical_accuracy: 0.8662 - val_loss: 0.2001 - val_categorical_accuracy: 0.8900
#
# Epoch 00006: saving model to model_init_2020-06-2615_32_34.928124/model-00006-0.35452-0.86576-0.20012-0.89000.h5
# Epoch 7/20
# 133/133 [==============================] - 84s 632ms/step - loss: 0.2992 - categorical_accuracy: 0.8945 - val_loss: 0.2507 - val_categorical_accuracy: 0.8800
#
# Epoch 00007: saving model to model_init_2020-06-2615_32_34.928124/model-00007-0.29715-0.89517-0.25070-0.88000.h5
# Epoch 8/20
# 133/133 [==============================] - 83s 626ms/step - loss: 0.3371 - categorical_accuracy: 0.8802 - val_loss: 0.5390 - val_categorical_accuracy: 0.7700
#
# Epoch 00008: saving model to model_init_2020-06-2615_32_34.928124/model-00008-0.33421-0.88084-0.53899-0.77000.h5
# Epoch 9/20
# 133/133 [==============================] - 83s 628ms/step - loss: 0.3175 - categorical_accuracy: 0.8880 - val_loss: 0.6386 - val_categorical_accuracy: 0.8000
#
# Epoch 00009: saving model to model_init_2020-06-2615_32_34.928124/model-00009-0.31743-0.88763-0.63864-0.80000.h5
# Epoch 10/20
# 133/133 [==============================] - 83s 625ms/step - loss: 0.3418 - categorical_accuracy: 0.8707 - val_loss: 0.5556 - val_categorical_accuracy: 0.8000
#
# Epoch 00010: saving model to model_init_2020-06-2615_32_34.928124/model-00010-0.34243-0.87029-0.55556-0.80000.h5
#
# Epoch 00010: ReduceLROnPlateau reducing learning rate to 0.00020000000949949026.
# Epoch 11/20
# 133/133 [==============================] - 82s 619ms/step - loss: 0.2793 - categorical_accuracy: 0.8995 - val_loss: 0.2533 - val_categorical_accuracy: 0.9100
#
# Epoch 00011: saving model to model_init_2020-06-2615_32_34.928124/model-00011-0.27947-0.89970-0.25327-0.91000.h5
# Epoch 12/20
# 133/133 [==============================] - 83s 626ms/step - loss: 0.1448 - categorical_accuracy: 0.9559 - val_loss: 0.2334 - val_categorical_accuracy: 0.9200
#
# Epoch 00012: saving model to model_init_2020-06-2615_32_34.928124/model-00012-0.14421-0.95626-0.23342-0.92000.h5
# Epoch 13/20
# 133/133 [==============================] - 84s 633ms/step - loss: 0.1219 - categorical_accuracy: 0.9609 - val_loss: 0.2642 - val_categorical_accuracy: 0.9000
#
# Epoch 00013: saving model to model_init_2020-06-2615_32_34.928124/model-00013-0.12212-0.96078-0.26422-0.90000.h5
# Epoch 14/20
# 133/133 [==============================] - 84s 635ms/step - loss: 0.0863 - categorical_accuracy: 0.9767 - val_loss: 0.2277 - val_categorical_accuracy: 0.9300
#
# Epoch 00014: saving model to model_init_2020-06-2615_32_34.928124/model-00014-0.08643-0.97662-0.22767-0.93000.h5
#
# Epoch 00014: ReduceLROnPlateau reducing learning rate to 4.0000001899898055e-05.
# Epoch 15/20
# 133/133 [==============================] - 84s 629ms/step - loss: 0.0661 - categorical_accuracy: 0.9820 - val_loss: 0.1973 - val_categorical_accuracy: 0.9400
#
# Epoch 00015: saving model to model_init_2020-06-2615_32_34.928124/model-00015-0.06615-0.98190-0.19731-0.94000.h5
# Epoch 16/20
# 133/133 [==============================] - 83s 625ms/step - loss: 0.0604 - categorical_accuracy: 0.9822 - val_loss: 0.1997 - val_categorical_accuracy: 0.9300
#
# Epoch 00016: saving model to model_init_2020-06-2615_32_34.928124/model-00016-0.05952-0.98265-0.19973-0.93000.h5
# Epoch 17/20
# 133/133 [==============================] - 83s 626ms/step - loss: 0.0616 - categorical_accuracy: 0.9805 - val_loss: 0.1960 - val_categorical_accuracy: 0.9400
#
# Epoch 00017: saving model to model_init_2020-06-2615_32_34.928124/model-00017-0.06172-0.98039-0.19597-0.94000.h5
# Epoch 18/20
# 133/133 [==============================] - 84s 631ms/step - loss: 0.0630 - categorical_accuracy: 0.9842 - val_loss: 0.2022 - val_categorical_accuracy: 0.9400
#
# Epoch 00018: saving model to model_init_2020-06-2615_32_34.928124/model-00018-0.06279-0.98416-0.20217-0.94000.h5
# Epoch 19/20
# 133/133 [==============================] - 83s 624ms/step - loss: 0.0347 - categorical_accuracy: 0.9925 - val_loss: 0.1991 - val_categorical_accuracy: 0.9400
#
# Epoch 00019: saving model to model_init_2020-06-2615_32_34.928124/model-00019-0.03474-0.99246-0.19909-0.94000.h5
# Epoch 20/20
# 133/133 [==============================] - 83s 628ms/step - loss: 0.0501 - categorical_accuracy: 0.9812 - val_loss: 0.2077 - val_categorical_accuracy: 0.9300
#
# Epoch 00020: saving model to model_init_2020-06-2615_32_34.928124/model-00020-0.05022-0.98115-0.20766-0.93000.h5

# %%
plot(history_model17)

# %% [markdown]
# #### Training accuracy    -  98%
# #### validation accuracy  -  93%

# %% [markdown]
# ### Final Verdict

# %% [markdown]
# ![Screenshot%202022-12-13%20232053.png](attachment:Screenshot%202022-12-13%20232053.png)

# %% [markdown]
# ## Model 7 - seems to be the top on the list of best performers, with less number of parameters and gave best validation result .
#
#
# __The best weights of CNN-LSTM: model-00020-0.19649-0.93514-0.45695-0.85000.h5 (19 MB). we considered this weight for model testing, Let's have look at the performance below__
